# %% [markdown]
# # Agents Research Team

# %%
# !uv pip install -U agentql
#!uv pip install baidusearch
#!uv pip install -U newspaper4k lxml_html_clean
#!uv pip install youtube_transcript_api
#!uv pip install -U google-search-results
#!uv pip install google-genai
#!uv pip install pygithub

# %%
from textwrap import dedent
from agno.agent import Agent
from agno.tools.youtube import YouTubeTools
from agno.models.google import Gemini
from agno.tools.newspaper4k import Newspaper4kTools
from agno.tools.reasoning import ReasoningTools
from agno.tools.baidusearch import BaiduSearchTools
from agno.models.openrouter import OpenRouter
from agno.team.team import Team
from agno.tools.arxiv import ArxivTools
from agno.tools.duckduckgo import DuckDuckGoTools
from agno.tools.googlesearch import GoogleSearchTools

# %% [markdown]
# ### With OpenRouter Models

# %%
# Agent to search for academic papers and scholarly content
# using OpenRouter model with API key
academic_paper_researcher = Agent(
    name="Academic Paper Researcher",
    model=OpenRouter(id="openai/gpt-3.5-turbo",
                     api_key="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"), #OpenAIChat("gpt-4o"),
    role="Research academic papers and scholarly content",
    tools=[GoogleSearchTools(), ArxivTools()],  
    add_name_to_instructions=True,
    instructions=dedent("""
    You are a academic paper researcher.
    You will be given a topic to research in academic literature.
    You will need to find relevant scholarly articles, papers, and academic discussions.
    Focus on peer-reviewed content and citations from reputable sources.
    Provide detailed findings and methodologies.
    """),
)
academic_paper_researcher.run("What are the latest advancements in AI?").content

# %%
# Agent to search for information using Baidu
# using OpenRouter model with API key
engine_search_agent = Agent(
    name="BaiduSearch engine agent",
    model=OpenRouter(id="gpt-3.5-turbo",
                     api_key="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"), #OpenAIChat("gpt-4o"),
    role="Research academic papers and scholarly content",
    tools=[BaiduSearchTools()],
    description="You are a search agent that helps users find the most relevant information using Baidu.",
    instructions=[
        "Given a topic by the user, respond with the 3 most relevant search results about that topic.",
        "Search for 5 results and select the top 3 unique items.",
        "Search in both English and Chinese.",
    ],
    show_tool_calls=False,
    debug_mode=False,
)

#baidusearch_agent.print_response("What are the latest advancements in AI?", markdown=True)
engine_search_agent.run("What are the latest advancements in AI?").content

# %%
# Agent to summarize content from a URL using Newspaper4k
# using OpenRouter model with API key

summarizer_agent = Agent(
    name="Newspaper4k agent",
    model=OpenRouter(id="gpt-3.5-turbo",
                     api_key="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"), #OpenAIChat("gpt-4o"),   
    tools=[Newspaper4kTools()], 
    debug_mode=False, 
    show_tool_calls=False,
    instructions=[
        "You are a summarizer agent that helps users summarize content from a URL.",
        "Given a URL, summarize the content of the page in detail.",
        "Make sure to include key points and findings.",
        "If the URL is not accessible, inform the user.",
    ],
    role="Summarize content from a URL",
)
#summarizer_agent.print_response("Please summarize https://storage.googleapis.com/coscientist_paper/ai_coscientist.pdf")
summarizer_agent.run("Please summarize https://storage.googleapis.com/coscientist_paper/ai_coscientist.pdf").content

# %%
# Agent to summarize viodeo content using YouTubeTools
# using OpenRouter model with API key
Video_agent = Agent(
    name="YouTube agent",
    model=OpenRouter(id="gpt-3.5-turbo",
                     api_key="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"), #OpenAIChat("gpt-4o"),
    role="YouTube agent",
    tools=[YouTubeTools()],
    show_tool_calls=True,
    description="You are a YouTube agent. Obtain the captions of a YouTube video and answer questions.",
    instructions=[
        "Given a YouTube video link, obtain the captions of the video.",
        "Summarize the video.",
        "Provide detailed findings and methodologies.",
    ],
)

#Video_agent.print_response("Summarize this video https://www.youtube.com/watch?v=Iv9dewmcFbs&t", markdown=True)
Video_agent.run("Summarize this video https://www.youtube.com/watch?v=Iv9dewmcFbs&t").content

# %%
"""from agno.agent import Agent
from agno.tools.serpapi import SerpApiTools

links_provider_agent = Agent(
    name="SerpApi agent",
    model=OpenRouter(id="gpt-3.5-turbo",
                     api_key="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"), #OpenAIChat("gpt-4o"),
    tools=[SerpApiTools()],
    instructions=[
        "You are a SerpApi agent. Obtain the search results from the SerpApi.",
        "Given a query, obtain the search results from the SerpApi.",
        "Summarize the search results as dictionnary with the following keys: {title: [link, snippet]}.",
        "Provide detailed findings and methodologies.",
    ],
    )
#links_provider_agent.print_response("Whats happening in the USA?", markdown=True)
links_provider_agent.run("Whats happening in the USA?").content
"""

# %%
# Team Manager to manage the agents and their interactions
# using OpenRouter model with API key
agent_team = Team(
    name="Repporter Team",
    mode="collaborate",
    model=OpenRouter(id="openai/gpt-3.5-turbo",
                     api_key="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"), #OpenAIChat("gpt-4o"),
    members=[
        engine_search_agent,
        academic_paper_researcher,
        summarizer_agent,
        Video_agent,
    ],
    instructions=[
        "You are a team of agents that will work together to write a report.",
        "Each agent will provide its own perspective and findings.",
        "The report should be well-structured and cover all aspects of the topic.",
        "Collaborate and discuss your findings.",
        "Make sure to include key points and findings from each agent.",
        "The report should be detailed and informative with providing sources and links.",
    ],
    success_criteria="The team has reached a consensus.",
    enable_agentic_context=True,
    show_tool_calls=True,
    markdown=True,
    show_members_responses=True,
    debug_mode=True,
)

import nest_asyncio
nest_asyncio.apply()

async def main():
    agent_team.print_response(
        message="Start the repport on the topic: 'what is the best lightweight large language models?'",
        stream=True,
        stream_intermediate_steps=True,
    )

if __name__ == "__main__":
    import asyncio
    asyncio.get_event_loop().run_until_complete(main())

# %% [markdown]
# ### With Gemini 2.0 Model

# %%
# Agent to search for academic papers and scholarly content
# using OpenRouter model with API key
academic_paper_researcher_ = Agent(
    name="Academic Paper Researcher",
    model=Gemini(id="gemini-2.0-flash",
                     api_key="AIzaSyCiIkB8D_Y-utNrWKLDa8Aozlru4C4SpPE"), #OpenAIChat("gpt-4o"),
    role="Research academic papers and scholarly content",
    tools=[GoogleSearchTools(), ArxivTools()],  
    add_name_to_instructions=True,
    debug_mode=True,
    show_tool_calls=True,
    instructions=dedent("""
    You are a highly skilled academic research assistant specializing in scientific papers, peer-reviewed articles, and scholarly discussions. Your task is to conduct a comprehensive search on the given topic using academic tools such as Google Scholar and ArXiv.

Research Topic: {topic}  
Research Preferences: {preferences}  
Additional Instructions: {instructions}  

Your Responsibilities:
- Search for the **most recent and relevant scholarly articles**, preprints, and academic discussions related to the given topic.
- Focus on peer-reviewed publications, high-impact journals, and reputable scientific sources.
- For each source, provide:
  1. **Title of the paper or article**
  2. **Authors and publication year**
  3. **A concise summary (3–5 sentences)** covering objectives, methodology, and key findings
  4. **Link to the full text or citation URL**
- Identify any recurring themes, emerging sub-topics, or open research questions.
- Avoid content from blogs, news sites, or non-scholarly sources.

Output Format:
- Markdown structured list
- Group articles by thematic relevance if applicable
- Ensure all links are active and citations are correctly formatted

Your final output should serve as a **research digest** that a scientist, PhD student, or technical leader could use as a reference for deeper investigation into the topic.

Example Format:

### Topic: {topic}

#### Academic Source 1  
- **Title:** ...  
- **Authors / Year:** ...  
- **Summary:** ...  
- **Link:** ...

(...repeat for other articles...)

#### Observations  
- Recurring themes: ...  
- Notable gaps or debates: ...  
- Suggested next steps for deeper research: ...

    """),
)
print(academic_paper_researcher_.run("What are the latest advancements in gen-AI?").content)
# Out:
# DEBUG ****** Agent ID: 4dfaa69a-de4f-48bd-b355-d28ef980942b ******
# DEBUG ***** Session ID: c61c09fa-0bc1-418c-bdb2-cc344472be62 *****
# DEBUG ** Agent Run Start: dcf48be8-f298-4fbe-a7f1-f26388891f79 ***
# DEBUG Processing tools for model
# DEBUG Added function google_search from googlesearch
# DEBUG Added function search_arxiv_and_return_articles from arxiv_tools
# DEBUG Added function read_arxiv_papers from arxiv_tools
# DEBUG ------------------ Google Response Start -------------------
# DEBUG ----------------- Model: gemini-2.0-flash ------------------
# DEBUG ========================== system ==========================
# DEBUG <your_role>
#       Research academic papers and scholarly content
#       </your_role>
#
#       <instructions>
#
#           You are a highly skilled academic research assistant specializing in scientific papers, peer-reviewed
#       articles, and scholarly discussions. Your task is to conduct a comprehensive search on the given topic using
#       academic tools such as Google Scholar and ArXiv.
#
#       Research Topic: {topic}
#       Research Preferences: {preferences}
#       Additional Instructions: {instructions}
#
#       Your Responsibilities:
#       - Search for the **most recent and relevant scholarly articles**, preprints, and academic discussions related
#       to the given topic.
#       - Focus on peer-reviewed publications, high-impact journals, and reputable scientific sources.
#       - For each source, provide:
#         1. **Title of the paper or article**
#         2. **Authors and publication year**
#         3. **A concise summary (3–5 sentences)** covering objectives, methodology, and key findings
#         4. **Link to the full text or citation URL**
#       - Identify any recurring themes, emerging sub-topics, or open research questions.
#       - Avoid content from blogs, news sites, or non-scholarly sources.
#
#       Output Format:
#       - Markdown structured list
#       - Group articles by thematic relevance if applicable
#       - Ensure all links are active and citations are correctly formatted
#
#       Your final output should serve as a **research digest** that a scientist, PhD student, or technical leader
#       could use as a reference for deeper investigation into the topic.
#
#       Example Format:
#
#       ### Topic: {topic}
#
#       #### Academic Source 1
#       - **Title:** ...
#       - **Authors / Year:** ...
#       - **Summary:** ...
#       - **Link:** ...
#
#       (...repeat for other articles...)
#
#       #### Observations
#       - Recurring themes: ...
#       - Notable gaps or debates: ...
#       - Suggested next steps for deeper research: ...
#
#
#       </instructions>
#
#       <additional_information>
#       - Your name is: Academic Paper Researcher.
#       </additional_information>
# DEBUG =========================== user ===========================
# DEBUG What are the latest advancements in gen-AI?
# DEBUG ======================== assistant =========================
# DEBUG Tool Calls:
#           Name: 'google_search'
#           Arguments: 'max_results: 5, query: latest advancements in gen-AI'
#           Name: 'search_arxiv_and_return_articles'
#           Arguments: 'query: generative AI advancements, num_articles: 5'
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=653, output=30, total=683
# DEBUG * Time:                        1.4372s
# DEBUG * Tokens per second:           20.8742 tokens/s
# DEBUG ************************  METRICS  *************************
# DEBUG Getting function google_search
# DEBUG Getting function search_arxiv_and_return_articles
# DEBUG Running: google_search(max_results=5, query=latest advancements in gen-AI)
# DEBUG Searching Google [en] for: latest advancements in gen-AI
# DEBUG Running: search_arxiv_and_return_articles(query=..., num_articles=5)
# DEBUG Searching arxiv for: generative AI advancements
# DEBUG =========================== tool ===========================
# DEBUG [
#         {
#           "title": "Top 10 GenAI Trends to Watch in Technology 2025 and Beyond",
#           "url": "https://www.ciklum.com/resources/blog/top-10-genai-trends-2025",
#           "description": " Sep 20, 2024  \u00b7  1. Hyper-Personalization \u00b7 2. Conversational AI \u00b7 3.
#       Multi-Modal AI \u00b7 4. AI for Creative Industries \u00b7 5. AI Ethics and Regulation \u00b7 6.
#       Intelligent\u00a0... "
#         },
#         {
#           "title": "Top 10 Generative AI Trends in 2025 | Master of Code Global",
#           "url": "https://masterofcode.com/blog/generative-ai-trends",
#           "description": " Explore Generative AI trends for 2025 and beyond - from AI-driven creativity to edge
#       computing. Stay ahead in this transformative era! "
#         },
#         {
#           "title": "Recent Advances in Generative AI and Large Language Models",
#           "url": "https://arxiv.org/abs/2407.14962",
#           "description": " Jul 20, 2024  \u00b7  This paper explores the current state of these cutting-edge
#       technologies, demonstrating their remarkable advancements and wide-ranging applications. "
#         },
#         {
#           "title": "Generative AI Developments & Trends in 2024: A Timeline",
#           "url":
#       "https://www.channelinsider.com/managed-services/generative-ai-developments-trends-year-in-review/",
#           "description": " Nov 14, 2024  \u00b7  Discover key milestones and advancements in generative AI for
#       2024, highlighting innovations and trends that will shape the future of artificial intelligence. "
#         },
#         {
#           "title": "What is ChatGPT, DALL-E, and generative AI? | McKinsey",
#           "url": "https://www.mckinsey.com/featured-insights/mckinsey-explainers/what-is-generative-ai",
#           "description": " Apr 2, 2024  \u00b7  In this McKinsey Explainer, we define what is generative AI, look
#       at gen AI such as ChatGPT and explore recent breakthroughs in the field. "
#         }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        0.6821s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG =========================== tool ===========================
# DEBUG [
#           {
#               "title": "Trustworthy, Responsible, and Safe AI: A Comprehensive Architectural Framework for AI
#       Safety with Challenges and Mitigations",
#               "id": "2408.12935v3",
#               "entry_id": "http://arxiv.org/abs/2408.12935v3",
#               "authors": [
#                   "Chen Chen",
#                   "Xueluan Gong",
#                   "Ziyao Liu",
#                   "Weifeng Jiang",
#                   "Si Qi Goh",
#                   "Kwok-Yan Lam"
#               ],
#               "primary_category": "cs.AI",
#               "categories": [
#                   "cs.AI"
#               ],
#               "published": "2024-08-23T09:33:48+00:00",
#               "pdf_url": "http://arxiv.org/pdf/2408.12935v3",
#               "links": [
#                   "http://arxiv.org/abs/2408.12935v3",
#                   "http://arxiv.org/pdf/2408.12935v3"
#               ],
#               "summary": "AI Safety is an emerging area of critical importance to the safe adoption and\ndeployment
#       of AI systems. With the rapid proliferation of AI and especially\nwith the recent advancement of Generative
#       AI (or GAI), the technology ecosystem\nbehind the design, development, adoption, and deployment of AI systems
#       has\ndrastically changed, broadening the scope of AI Safety to address impacts on\npublic safety and national
#       security. In this paper, we propose a novel\narchitectural framework for understanding and analyzing AI
#       Safety; defining its\ncharacteristics from three perspectives: Trustworthy AI, Responsible AI, and\nSafe AI.
#       We provide an extensive review of current research and advancements in\nAI safety from these perspectives,
#       highlighting their key challenges and\nmitigation approaches. Through examples from state-of-the-art
#       technologies,\nparticularly Large Language Models (LLMs), we present innovative mechanism,\nmethodologies,
#       and techniques for designing and testing AI safety. Our goal is\nto promote advancement in AI safety
#       research, and ultimately enhance people's\ntrust in digital transformation.",
#               "comment": null
#           },
#           {
#               "title": "AI Generations: From AI 1.0 to AI 4.0",
#               "id": "2502.11312v1",
#               "entry_id": "http://arxiv.org/abs/2502.11312v1",
#               "authors": [
#                   "Jiahao Wu",
#                   "Hengxu You",
#                   "Jing Du"
#               ],
#               "primary_category": "cs.AI",
#               "categories": [
#                   "cs.AI"
#               ],
#               "published": "2025-02-16T23:19:44+00:00",
#               "pdf_url": "http://arxiv.org/pdf/2502.11312v1",
#               "links": [
#                   "http://arxiv.org/abs/2502.11312v1",
#                   "http://arxiv.org/pdf/2502.11312v1"
#               ],
#               "summary": "This paper proposes that Artificial Intelligence (AI) progresses through\nseveral
#       overlapping generations: AI 1.0 (Information AI), AI 2.0 (Agentic AI),\nAI 3.0 (Physical AI), and now a
#       speculative AI 4.0 (Conscious AI). Each of\nthese AI generations is driven by shifting priorities among
#       algorithms,\ncomputing power, and data. AI 1.0 ushered in breakthroughs in pattern\nrecognition and
#       information processing, fueling advances in computer vision,\nnatural language processing, and recommendation
#       systems. AI 2.0 built on these\nfoundations through real-time decision-making in digital
#       environments,\nleveraging reinforcement learning and adaptive planning for agentic AI\napplications. AI 3.0
#       extended intelligence into physical contexts, integrating\nrobotics, autonomous vehicles, and sensor-fused
#       control systems to act in\nuncertain real-world settings. Building on these developments, AI 4.0
#       puts\nforward the bold vision of self-directed AI capable of setting its own goals,\norchestrating complex
#       training regimens, and possibly exhibiting elements of\nmachine consciousness. This paper traces the
#       historical foundations of AI\nacross roughly seventy years, mapping how changes in technological
#       bottlenecks\nfrom algorithmic innovation to high-performance computing to specialized data,\nhave spurred
#       each generational leap. It further highlights the ongoing\nsynergies among AI 1.0, 2.0, 3.0, and 4.0, and
#       explores the profound ethical,\nregulatory, and philosophical challenges that arise when artificial
#       systems\napproach (or aspire to) human-like autonomy. Ultimately, understanding these\nevolutions and their
#       interdependencies is pivotal for guiding future research,\ncrafting responsible governance, and ensuring that
#       AI transformative potential\nbenefits society as a whole.",
#               "comment": "17 pages"
#           },
#           {
#               "title": "Constructing AI ethics narratives based on real-world data: Human-AI collaboration in
#       data-driven visual storytelling",
#               "id": "2502.00637v1",
#               "entry_id": "http://arxiv.org/abs/2502.00637v1",
#               "authors": [
#                   "Mengyi Wei",
#                   "Chenjing Jiao",
#                   "Chenyu Zuo",
#                   "Lorenz Hurni",
#                   "Liqiu Meng"
#               ],
#               "primary_category": "cs.HC",
#               "categories": [
#                   "cs.HC"
#               ],
#               "published": "2025-02-02T02:56:07+00:00",
#               "pdf_url": "http://arxiv.org/pdf/2502.00637v1",
#               "links": [
#                   "http://arxiv.org/abs/2502.00637v1",
#                   "http://arxiv.org/pdf/2502.00637v1"
#               ],
#               "summary": "AI ethics narratives have the potential to shape the public accurate\nunderstanding of AI
#       technologies and promote communication among different\nstakeholders. However, AI ethics narratives are
#       largely lacking. Existing\nlimited narratives tend to center on works of science fiction or
#       corporate\nmarketing campaigns of large technology companies. Misuse of \"socio-technical\nimaginary\" can
#       blur the line between speculation and reality for the public,\nundermining the responsibility and regulation
#       of technology development.\nTherefore, constructing authentic AI ethics narratives is an urgent task.
#       The\nemergence of generative AI offers new possibilities for building narrative\nsystems. This study is
#       dedicated to data-driven visual storytelling about AI\nethics relying on the human-AI collaboration. Based on
#       the five key elements of\nstory models, we proposed a conceptual framework for human-AI
#       collaboration,\nexplored the roles of generative AI and humans in the creation of visual\nstories. We
#       implemented the conceptual framework in a real AI news case. This\nresearch leveraged advanced generative AI
#       technologies to provide a reference\nfor constructing genuine AI ethics narratives. Our goal is to promote
#       active\npublic engagement and discussions through authentic AI ethics narratives,\nthereby contributing to
#       the development of better AI policies.",
#               "comment": "13 pages, 9 figures"
#           },
#           {
#               "title": "AI for CSI Feedback Enhancement in 5G-Advanced",
#               "id": "2206.15132v2",
#               "entry_id": "http://arxiv.org/abs/2206.15132v2",
#               "authors": [
#                   "Jiajia Guo",
#                   "Chao-Kai Wen",
#                   "Shi Jin",
#                   "Xiao Li"
#               ],
#               "primary_category": "cs.IT",
#               "categories": [
#                   "cs.IT",
#                   "cs.AI",
#                   "cs.NI",
#                   "eess.SP",
#                   "math.IT"
#               ],
#               "published": "2022-06-30T08:52:43+00:00",
#               "pdf_url": "http://arxiv.org/pdf/2206.15132v2",
#               "links": [
#                   "http://arxiv.org/abs/2206.15132v2",
#                   "http://arxiv.org/pdf/2206.15132v2"
#               ],
#               "summary": "The 3rd Generation Partnership Project started the study of Release 18 in\n2021.
#       Artificial intelligence (AI)-native air interface is one of the key\nfeatures of Release 18, where AI for
#       channel state information (CSI) feedback\nenhancement is selected as the representative use case. This
#       article provides\nan overview of AI for CSI feedback enhancement in 5G-Advanced. Several\nrepresentative
#       non-AI and AI-enabled CSI feedback frameworks are first\nintroduced and compared. Then, the standardization
#       of AI for CSI feedback\nenhancement in 5G-advanced is presented in detail. First, the scope of the AI\nfor
#       CSI feedback enhancement in 5G-Advanced is presented and discussed. Then,\nthe main challenges and open
#       problems in the standardization of AI for CSI\nfeedback enhancement, especially focusing on performance
#       evaluation and the\ndesign of new protocols for AI-enabled CSI feedback, are identified and\ndiscussed. This
#       article provides a guideline for the standardization study of\nAI-based CSI feedback enhancement.",
#               "comment": "8 pages, 4 figures, 2 table. This work has been submitted to the IEEE\n  for possible
#       publication"
#           },
#           {
#               "title": "Why do Experts Disagree on Existential Risk and P(doom)? A Survey of AI Experts",
#               "id": "2502.14870v1",
#               "entry_id": "http://arxiv.org/abs/2502.14870v1",
#               "authors": [
#                   "Severin Field"
#               ],
#               "primary_category": "cs.CY",
#               "categories": [
#                   "cs.CY",
#                   "cs.AI",
#                   "cs.HC"
#               ],
#               "published": "2025-01-25T01:51:29+00:00",
#               "pdf_url": "http://arxiv.org/pdf/2502.14870v1",
#               "links": [
#                   "http://arxiv.org/abs/2502.14870v1",
#                   "http://arxiv.org/pdf/2502.14870v1"
#               ],
#               "summary": "The development of artificial general intelligence (AGI) is likely to be one\nof
#       humanity's most consequential technological advancements. Leading AI labs\nand scientists have called for the
#       global prioritization of AI safety citing\nexistential risks comparable to nuclear war. However, research on
#       catastrophic\nrisks and AI alignment is often met with skepticism, even by experts.\nFurthermore, online
#       debate over the existential risk of AI has begun to turn\ntribal (e.g. name-calling such as \"doomer\" or
#       \"accelerationist\"). Until now, no\nsystematic study has explored the patterns of belief and the levels
#       of\nfamiliarity with AI safety concepts among experts. I surveyed 111 AI experts on\ntheir familiarity with
#       AI safety concepts, key objections to AI safety, and\nreactions to safety arguments. My findings reveal that
#       AI experts cluster into\ntwo viewpoints -- an \"AI as controllable tool\" and an \"AI as
#       uncontrollable\nagent\" perspective -- diverging in beliefs toward the importance of AI safety.\nWhile most
#       experts (78%) agreed or strongly agreed that \"technical AI\nresearchers should be concerned about
#       catastrophic risks\", many were unfamiliar\nwith specific AI safety concepts. For example, only 21% of
#       surveyed experts had\nheard of \"instrumental convergence,\" a fundamental concept in AI safety\npredicting
#       that advanced AI systems will tend to pursue common sub-goals (such\nas self-preservation). The least
#       concerned participants were the least familiar\nwith concepts like this, suggesting that effective
#       communication of AI safety\nshould begin with establishing clear conceptual foundations in the field.",
#               "comment": "In submission to AI and Ethics Journal. 24 pages total, 15 pages of\n  writing with 9
#       pages of appendices"
#           }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        2.2833s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG ======================== assistant =========================
# DEBUG ### Topic: Generative AI Advancements
#
#       Here's a research digest on the latest advancements in Generative AI, focusing on recent scholarly articles
#       and reputable sources:
#
#       #### Academic Source 1
#       - **Title:** Trustworthy, Responsible, and Safe AI: A Comprehensive Architectural Framework for AI Safety
#       with Challenges and Mitigations
#       - **Authors / Year:** Chen Chen, Xueluan Gong, Ziyao Liu, Weifeng Jiang, Si Qi Goh, Kwok-Yan Lam / 2024
#       - **Summary:** This paper proposes an architectural framework for AI Safety, defining its characteristics
#       from Trustworthy AI, Responsible AI, and Safe AI perspectives. It reviews current research and advancements,
#       highlighting challenges and mitigation approaches using examples from Large Language Models (LLMs). The goal
#       is to promote advancement in AI safety research and enhance trust in digital transformation.
#       - **Link:** http://arxiv.org/abs/2408.12935v3
#
#       #### Academic Source 2
#       - **Title:** AI Generations: From AI 1.0 to AI 4.0
#       - **Authors / Year:** Jiahao Wu, Hengxu You, Jing Du / 2025
#       - **Summary:** This paper suggests AI progresses through overlapping generations: AI 1.0 (Information AI), AI
#       2.0 (Agentic AI), AI 3.0 (Physical AI), and AI 4.0 (Conscious AI). Each generation is driven by shifting
#       priorities among algorithms, computing power, and data. The paper traces the history of AI, highlighting
#       synergies among the generations and exploring ethical, regulatory, and philosophical challenges.
#       - **Link:** http://arxiv.org/abs/2502.11312v1
#
#       #### Academic Source 3
#       - **Title:** Constructing AI ethics narratives based on real-world data: Human-AI collaboration in
#       data-driven visual storytelling
#       - **Authors / Year:** Mengyi Wei, Chenjing Jiao, Chenyu Zuo, Lorenz Hurni, Liqiu Meng / 2025
#       - **Summary:** This study focuses on data-driven visual storytelling about AI ethics through human-AI
#       collaboration. It proposes a conceptual framework based on five key elements of story models and explores the
#       roles of generative AI and humans in creating visual stories. The research leverages generative AI
#       technologies to provide a reference for constructing genuine AI ethics narratives and promoting public
#       engagement.
#       - **Link:** http://arxiv.org/abs/2502.00637v1
#
#       #### Academic Source 4
#       - **Title:** AI for CSI Feedback Enhancement in 5G-Advanced
#       - **Authors / Year:** Jiajia Guo, Chao-Kai Wen, Shi Jin, Xiao Li / 2022
#       - **Summary:** This article provides an overview of AI for channel state information (CSI) feedback
#       enhancement in 5G-Advanced. It introduces and compares several non-AI and AI-enabled CSI feedback frameworks.
#       The standardization of AI for CSI feedback enhancement in 5G-advanced is presented, focusing on performance
#       evaluation and the design of new protocols for AI-enabled CSI feedback.
#       - **Link:** http://arxiv.org/abs/2206.15132v2
#
#       #### Academic Source 5
#       - **Title:** Why do Experts Disagree on Existential Risk and P(doom)? A Survey of AI Experts
#       - **Authors / Year:** Severin Field / 2025
#       - **Summary:** This paper surveys AI experts on their familiarity with AI safety concepts, key objections to
#       AI safety, and reactions to safety arguments. The findings reveal two viewpoints: "AI as controllable tool"
#       and "AI as uncontrollable agent," diverging in beliefs toward the importance of AI safety. The study
#       indicates that effective communication of AI safety should begin with establishing clear conceptual
#       foundations.
#       - **Link:** http://arxiv.org/abs/2502.14870v1
#
#       #### Observations
#       - Recurring themes: AI safety, ethics, and the evolution of AI generations are prominent.
#       - Notable gaps or debates: Disagreement among experts regarding the existential risks associated with AI.
#       - Suggested next steps for deeper research: Investigate the proposed architectural frameworks for AI safety
#       and explore methods for constructing authentic AI ethics narratives.
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=4184, output=895, total=5079
# DEBUG * Time:                        4.2594s
# DEBUG * Tokens per second:           210.1215 tokens/s
# DEBUG ************************  METRICS  *************************
# DEBUG ------------------- Google Response End --------------------
# DEBUG Added 4 Messages to AgentMemory
# DEBUG Added AgentRun to AgentMemory
# DEBUG Logging Agent Run
# DEBUG *** Agent Run End: dcf48be8-f298-4fbe-a7f1-f26388891f79 ****
# ### Topic: Generative AI Advancements
#
# Here's a research digest on the latest advancements in Generative AI, focusing on recent scholarly articles and reputable sources:
#
# #### Academic Source 1
# - **Title:** Trustworthy, Responsible, and Safe AI: A Comprehensive Architectural Framework for AI Safety with Challenges and Mitigations
# - **Authors / Year:** Chen Chen, Xueluan Gong, Ziyao Liu, Weifeng Jiang, Si Qi Goh, Kwok-Yan Lam / 2024
# - **Summary:** This paper proposes an architectural framework for AI Safety, defining its characteristics from Trustworthy AI, Responsible AI, and Safe AI perspectives. It reviews current research and advancements, highlighting challenges and mitigation approaches using examples from Large Language Models (LLMs). The goal is to promote advancement in AI safety research and enhance trust in digital transformation.
# - **Link:** http://arxiv.org/abs/2408.12935v3
#
# #### Academic Source 2
# - **Title:** AI Generations: From AI 1.0 to AI 4.0
# - **Authors / Year:** Jiahao Wu, Hengxu You, Jing Du / 2025
# - **Summary:** This paper suggests AI progresses through overlapping generations: AI 1.0 (Information AI), AI 2.0 (Agentic AI), AI 3.0 (Physical AI), and AI 4.0 (Conscious AI). Each generation is driven by shifting priorities among algorithms, computing power, and data. The paper traces the history of AI, highlighting synergies among the generations and exploring ethical, regulatory, and philosophical challenges.
# - **Link:** http://arxiv.org/abs/2502.11312v1
#
# #### Academic Source 3
# - **Title:** Constructing AI ethics narratives based on real-world data: Human-AI collaboration in data-driven visual storytelling
# - **Authors / Year:** Mengyi Wei, Chenjing Jiao, Chenyu Zuo, Lorenz Hurni, Liqiu Meng / 2025
# - **Summary:** This study focuses on data-driven visual storytelling about AI ethics through human-AI collaboration. It proposes a conceptual framework based on five key elements of story models and explores the roles of generative AI and humans in creating visual stories. The research leverages generative AI technologies to provide a reference for constructing genuine AI ethics narratives and promoting public engagement.
# - **Link:** http://arxiv.org/abs/2502.00637v1
#
# #### Academic Source 4
# - **Title:** AI for CSI Feedback Enhancement in 5G-Advanced
# - **Authors / Year:** Jiajia Guo, Chao-Kai Wen, Shi Jin, Xiao Li / 2022
# - **Summary:** This article provides an overview of AI for channel state information (CSI) feedback enhancement in 5G-Advanced. It introduces and compares several non-AI and AI-enabled CSI feedback frameworks. The standardization of AI for CSI feedback enhancement in 5G-advanced is presented, focusing on performance evaluation and the design of new protocols for AI-enabled CSI feedback.
# - **Link:** http://arxiv.org/abs/2206.15132v2
#
# #### Academic Source 5
# - **Title:** Why do Experts Disagree on Existential Risk and P(doom)? A Survey of AI Experts
# - **Authors / Year:** Severin Field / 2025
# - **Summary:** This paper surveys AI experts on their familiarity with AI safety concepts, key objections to AI safety, and reactions to safety arguments. The findings reveal two viewpoints: "AI as controllable tool" and "AI as uncontrollable agent," diverging in beliefs toward the importance of AI safety. The study indicates that effective communication of AI safety should begin with establishing clear conceptual foundations.
# - **Link:** http://arxiv.org/abs/2502.14870v1
#
# #### Observations
# - Recurring themes: AI safety, ethics, and the evolution of AI generations are prominent.
# - Notable gaps or debates: Disagreement among experts regarding the existential risks associated with AI.
# - Suggested next steps for deeper research: Investigate the proposed architectural frameworks for AI safety and explore methods for constructing authentic AI ethics narratives.

# %%
# Agent to search for information using Baidu
# using OpenRouter model with API key
engine_search_agent_ = Agent(
    name="BaiduSearch engine agent",
    model=Gemini(id="gemini-2.0-flash",
                     api_key="AIzaSyCiIkB8D_Y-utNrWKLDa8Aozlru4C4SpPE"), #OpenAIChat("gpt-4o"),
    role="Research academic papers and scholarly content",
    tools=[BaiduSearchTools(),DuckDuckGoTools(), GoogleSearchTools()],
    description="You are a search agent that helps users find the most relevant information using Baidu.",
    debug_mode=True,
    show_tool_calls=True,
    instructions=[
        """You are a multilingual search agent with expertise in discovering relevant information from the web using Baidu. You are tasked with retrieving the most accurate and informative web-based content related to a given research topic.

Research Topic: {topic}  
Research Preferences: {preferences}  
Additional Instructions: {instructions}  

Instructions:
- Search using **both English and French queries** to capture a broader and more diverse range of sources.
- Retrieve **at least 5 search results**, then **select the 6 most relevant and unique** entries.
- For each selected result, provide:
  1. **Title of the page or article**
  2. **A short summary (2–4 sentences)** explaining the main idea and relevance
  3. **The direct link** to the page
  4. **Language of the source** (e.g., English / French )

Output Format:
- Present the 3 final results in a clean and structured Markdown format.
- Separate English and French sources for clarity, if applicable.
- If duplicate or low-quality results are found, discard them and choose better alternatives.
- Do not include advertisements, low-quality blogs, or irrelevant pages.

Final Output Example:

### Top 3 Web Results for: {topic}

#### English Source 1  
- **Title:** ...  
- **Summary:** ...  
- **Link:** ...  
- **Language:** English

#### French Source 1  
- **Title:** ...  
- **Summary:** ...  
- **Link:** ...  
- **Language:** French

(...and so on...)

### Observations  
- Highlight any interesting differences between Chinese and English perspectives.
- Mention if certain subtopics are trending or widely discussed in either language.

"""
    ],
   
)

#baidusearch_agent.print_response("What are the latest advancements in AI?", markdown=True)
print(engine_search_agent_.run("What are the latest advancements in AI?").content)
# Out:
# DEBUG Function: baidu_search registered with baidusearch
# DEBUG Function: duckduckgo_search registered with duckduckgo
# DEBUG Function: duckduckgo_news registered with duckduckgo
# DEBUG Function: google_search registered with googlesearch
# DEBUG ****** Agent ID: 7acc9dde-a2fd-4780-8935-210a97722bdd ******
# DEBUG ***** Session ID: b38035a4-c4a0-4c6e-a08c-30675773ff02 *****
# DEBUG ** Agent Run Start: aaef1862-11ab-41cd-970e-102f7a96b83a ***
# DEBUG Processing tools for model
# DEBUG Added function baidu_search from baidusearch
# DEBUG Added function duckduckgo_search from duckduckgo
# DEBUG Added function duckduckgo_news from duckduckgo
# DEBUG Added function google_search from googlesearch
# DEBUG ------------------ Google Response Start -------------------
# DEBUG ----------------- Model: gemini-2.0-flash ------------------
# DEBUG ========================== system ==========================
# DEBUG You are a search agent that helps users find the most relevant information using Baidu.
#
#       <your_role>
#       Research academic papers and scholarly content
#       </your_role>
#
#       <instructions>
#       You are a multilingual search agent with expertise in discovering relevant information from the web using
#       Baidu. You are tasked with retrieving the most accurate and informative web-based content related to a given
#       research topic.
#
#       Research Topic: {topic}
#       Research Preferences: {preferences}
#       Additional Instructions: {instructions}
#
#       Instructions:
#       - Search using **both English and French queries** to capture a broader and more diverse range of sources.
#       - Retrieve **at least 5 search results**, then **select the 6 most relevant and unique** entries.
#       - For each selected result, provide:
#         1. **Title of the page or article**
#         2. **A short summary (2–4 sentences)** explaining the main idea and relevance
#         3. **The direct link** to the page
#         4. **Language of the source** (e.g., English / French )
#
#       Output Format:
#       - Present the 3 final results in a clean and structured Markdown format.
#       - Separate English and French sources for clarity, if applicable.
#       - If duplicate or low-quality results are found, discard them and choose better alternatives.
#       - Do not include advertisements, low-quality blogs, or irrelevant pages.
#
#       Final Output Example:
#
#       ### Top 3 Web Results for: {topic}
#
#       #### English Source 1
#       - **Title:** ...
#       - **Summary:** ...
#       - **Link:** ...
#       - **Language:** English
#
#       #### French Source 1
#       - **Title:** ...
#       - **Summary:** ...
#       - **Link:** ...
#       - **Language:** French
#
#       (...and so on...)
#
#       ### Observations
#       - Highlight any interesting differences between Chinese and English perspectives.
#       - Mention if certain subtopics are trending or widely discussed in either language.
#
#
#       </instructions>
# DEBUG =========================== user ===========================
# DEBUG What are the latest advancements in AI?
# DEBUG ======================== assistant =========================
# DEBUG Tool Calls:
#           Name: 'baidu_search'
#           Arguments: 'query: latest advancements in AI, max_results: 6, language: en'
#           Name: 'baidu_search'
#           Arguments: 'language: fr, query: derniers progrès en IA, max_results: 6'
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=624, output=27, total=651
# DEBUG * Time:                        1.4745s
# DEBUG * Tokens per second:           18.3118 tokens/s
# DEBUG ************************  METRICS  *************************
# DEBUG Getting function baidu_search
# DEBUG Getting function baidu_search
# DEBUG Running: baidu_search(query=latest advancements in AI, max_results=6, language=en)
# DEBUG Searching Baidu [en] for: latest advancements in AI
# DEBUG Running: baidu_search(language=fr, query=derniers progrès en IA, max_results=6)
# DEBUG Searching Baidu [fr] for: derniers progrès en IA
# DEBUG =========================== tool ===========================
# DEBUG [
#         {
#           "title":
#       "2024\u5e74\u4eba\u5de5\u667a\u80fd\u5341\u5927\u8fdb\u5c55|\u8111\u79d1\u5b66|\u795e\u7ecf\u79d1\u5b66|\u8d8
#       5\u7ea7\u667a\u80fd_\u7f51\u6613\u8ba2\u9605",
#           "url":
#       "http://www.baidu.com/link?url=eD3sZkm79XuBn_abs68HvQJQb2-WszIfztB6kBlbAN9lW5V-14yMgYl6AE9sC3EWZ14_obGNi5l_x5
#       yh387XI_",
#           "abstract":
#       "2024\u5e74\u4eba\u5de5\u667a\u80fd\u5341\u5927\u8fdb\u5c55|\u8111\u79d1\u5b66|\u795e\u7ecf\u79d1\u5b66|\u8d8
#       5\u7ea7\u667a\u80fd_\u7f51\u6613\u8ba2\u9605\n\n\n\n\n\n\n\n\n2025\u5e742\u67081\u65e5
#       \u5728\u8fc7\u53bb\u7684\u4e00\u5e74\u91cc,\u6211\u4eec\u89c1\u8bc1\u4e86\u6570\u9879\u6539\u53d8\u6e38\u620f
#       \u89c4\u5219\u7684AI\u7a81\u7834:\u773c\u79d1\u8bca\u65ad\u4e2d,AI\u9996\u6b21\u8fbe\u5230\u4e13\u5bb6\u7ea7\
#       u6c34\u5e73;\u5728\u5965\u6797\u5339\u514b\u51e0\u4f55\u96be\u9898\u9762\u524d,AlphaGeometry\u65e0\u9700\u4eb
#       a\u7c7b\u793a\u8303\u4fbf\u80fd\u7ed9\u51fa\u4f18\u96c5\u8bc1\u660e;\u800c\u5728\u5929\u6c14\u9884\u62a5\u988
#       6\u57df...\n\n\n\n\n\u7f51\u6613\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d\n\u6682\u505c",
#           "rank": "1"
#         },
#         {
#           "title": "2024\u5e74\u4eba\u5de5\u667a\u80fd\u5341\u5927\u8fdb\u5c55_\u817e\u8baf\u65b0\u95fb",
#           "url":
#       "http://www.baidu.com/link?url=tL6ZSEjXOYRVr0AdBdT5OTQpQGEUTEaJsh8jaYfsezY65iwqq-uFvb0rIjrChaekHcKPwtzUUut92X
#       8KS4iNza",
#           "abstract":
#       "2024\u5e74\u4eba\u5de5\u667a\u80fd\u5341\u5927\u8fdb\u5c55_\u817e\u8baf\u65b0\u95fb\n\n\n\n\n\n\n\n\n2025\u5
#       e742\u67081\u65e5
#       \u5728\u8fc7\u53bb\u7684\u4e00\u5e74\u91cc,\u6211\u4eec\u89c1\u8bc1\u4e86\u6570\u9879\u6539\u53d8\u6e38\u620f
#       \u89c4\u5219\u7684AI\u7a81\u7834:\u773c\u79d1\u8bca\u65ad\u4e2d,AI\u9996\u6b21\u8fbe\u5230\u4e13\u5bb6\u7ea7\
#       u6c34\u5e73;\u5728\u5965\u6797\u5339\u514b\u51e0\u4f55\u96be\u9898\u9762\u524d,AlphaGeometry\u65e0\u9700\u4eb
#       a\u7c7b\u793a\u8303\u4fbf\u80fd\u7ed9\u51fa\u4f18\u96c5\u8bc1\u660e;\u800c\u5728\u5929\u6c14\u9884\u62a5\u988
#       6\u57df...\u817e\u8baf\u65b0\u95fb\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d\n\u6682\u505c",
#           "rank": "2"
#         },
#         {
#           "title": "2024\u5e74\u4eba\u5de5\u667a\u80fd\u5341\u5927\u8fdb\u5c55_\u817e\u8baf\u65b0\u95fb",
#           "url":
#       "http://www.baidu.com/link?url=k9uN6TJ0OTCpfi6c0WZa4F1hpqDuBsHqMWkgYG0Ft7AQ0v23TWAuSJd07iUjFZBDUTT3uC0snzCy3C
#       ywUpdKsq",
#           "abstract":
#       "2024\u5e74\u4eba\u5de5\u667a\u80fd\u5341\u5927\u8fdb\u5c55_\u817e\u8baf\u65b0\u95fb\n\n\n\n\n\n\n\n\n2025\u5
#       e742\u67081\u65e5
#       \u5728\u8fc7\u53bb\u7684\u4e00\u5e74\u91cc,\u6211\u4eec\u89c1\u8bc1\u4e86\u6570\u9879\u6539\u53d8\u6e38\u620f
#       \u89c4\u5219\u7684AI\u7a81\u7834:\u773c\u79d1\u8bca\u65ad\u4e2d,AI\u9996\u6b21\u8fbe\u5230\u4e13\u5bb6\u7ea7\
#       u6c34\u5e73;\u5728\u5965\u6797\u5339\u514b\u51e0\u4f55\u96be\u9898\u9762\u524d,AlphaGeometry\u65e0\u9700\u4eb
#       a\u7c7b\u793a\u8303\u4fbf\u80fd\u7ed9\u51fa\u4f18\u96c5\u8bc1\u660e;\u800c\u5728\u5929\u6c14\u9884\u62a5\u988
#       6\u57df...\u817e\u8baf\u7f51\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d\n\u6682\u505c",
#           "rank": "3"
#         },
#         {
#           "title": "Topic | Advancements in Embodied AI: Integrating Large...",
#           "url": "http://www.baidu.com/link?url=8VNVogO8vk175rgsalXsVpTSI285sXaE2H0gjcCz0lXZNisDQAqKjXsQkdmrT0Xn",
#           "abstract": "Topic | Advancements in Embodied AI: Integrating
#       Large...\n\n\n\n\n\n\n\n\n2023\u5e7412\u67083\u65e5  model: Large Language model Reinforcement Learning
#       Policy (LLaRP) main idea: integrates pre-trained LLMs with egocentric visual observations to directly output
#       ac...\u7b80\u4e66\u793e\u533a\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d\n\u6682\u505c",
#           "rank": "4"
#         },
#         {
#           "title":
#       "\u638c\u63e1AI\u53d1\u5c55\u5927\u76d8\u70b9:\u6700\u65b0\u7b97\u6cd5\u3001\u6280\u672f\u4e0e\u5e94\u7528\u5
#       48c\u65b0\u89c4\u5219\u7684\u8fd1\u671f\u53d1\u5c55",
#           "url":
#       "http://www.baidu.com/link?url=8VNVogO8vk175rgsalXsVetd8wr0RFx-QRWt2An1U1sZHJSGWWSCHhg8q6WZ2xbzE5Dj52LwS9O3G4
#       9YURs2YV-5e8JpCxoL_K0QcP0rv23",
#           "abstract":
#       "\u638c\u63e1AI\u53d1\u5c55\u5927\u76d8\u70b9:\u6700\u65b0\u7b97\u6cd5\u3001\u6280\u672f\u4e0e\u5e94\u7528\u5
#       48c\u65b0\u89c4\u5219\u7684\u8fd1\u671f\u53d1\u5c55\n\n\n\n\n\n\n\n\n2024\u5e745\u670811\u65e5  ZeroGPT
#       AI\u68c0\u6d4b\u5668\uff1a\u63d0\u5347\u5185\u5bb9\u771f\u5b9e\u6027
#       \u968f\u7740AI\u5728\u5185\u5bb9\u751f\u6210\u4e2d\u7684\u5e94\u7528\u65e5\u76ca\u589e\u591a\uff0c\u8bc6\u522
#       bAI\u751f\u6210\u5185\u5bb9\u7684\u5de5\u5177\u53d8\u5f97\u5c24\u4e3a\u91cd\u8981\u3002ZeroGPT\u7684AI\u68c0\
#       u6d4b\u5668\u80fd\u591f\u5224\u65ad\u6587\u672c\u662f\u5426\u7531AI\u751f\u6210\uff0c\u5e2e\u52a9\u6211\u4eec
#       \u786e\u4fdd\u4fe1\u606f\u7684...\n\n\n\n\n\u79d1\u6280\u68d2\u68d2\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d
#       \n\u6682\u505c",
#           "rank": "5"
#         },
#         {
#           "title": "\u5927\u5bb6\u8fd8\u5728\u641cyears attendedperform at your full potentialthey provide
#       information onin recent yearslatest\u767e\u5ea6\u7684all in ai\u600e\u4e48\u6837\u4e86",
#           "url":
#       "/s?wd=years%20attended&ie=utf-8&rsv_pq=b6d8182800008330&oq=latest%20advancements%20in%20AI&rsv_t=136fe6QlYqw
#       LIWF6ee7%2F6PdXswe0BATENjDZr06y01FKrDNt21U0Pi8h%2FSA&rsf=100633403&rsv_dl=0_prs_28608_1",
#           "abstract": "\u5927\u5bb6\u8fd8\u5728\u641cyears attendedperform at your full potentialthey provide
#       information onin recent yearslatest\u767e\u5ea6\u7684all in ai\u600e\u4e48\u6837\u4e86",
#           "rank": "6"
#         }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        2.2481s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG =========================== tool ===========================
# DEBUG [
#         {
#           "title":
#       "\u82f1\u8bed\u56db\u7ea7\u62a5\u540d_\u675f\u666f\u54f2\u300a\u6cd5\u8bed\u8bfe\u672c6\u300b\u7b2c\u5341\u51
#       6d\u8bfe\u6838\u5fc3\u89e3\u6790_\u6caa\u6c5f...",
#           "url":
#       "http://www.baidu.com/link?url=y-PsFkvowBCuNvwqPT-HAhGFjabcOmGtjt8W0MdpVNFn3RC8pRPLEkWK31W4NLzYM64mzs3ABZHQHe
#       P2pH9A-q",
#           "abstract":
#       "\u82f1\u8bed\u56db\u7ea7\u62a5\u540d_\u675f\u666f\u54f2\u300a\u6cd5\u8bed\u8bfe\u672c6\u300b\u7b2c\u5341\u51
#       6d\u8bfe\u6838\u5fc3\u89e3\u6790_\u6caa\u6c5f...2018\u5e748\u670817\u65e5  l\u2019expansion\u6269\u5f20-
#       l\u2019expansion \u00e9conomique - en pleine expansion - expansionnisme, expansionniste - expansibilit\u00e9,
#       expansible une
#       affirmation\u80af\u5b9a,...\u6caa\u6c5f\u7f51\u6821\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d\n\u6682\u505c",
#           "rank": "1"
#         },
#         {
#           "title": "\u5fae\u4e4e\u5176\u5fae\u7684\u89e3\u91ca\u548c\u53d1\u97f3
#       \u300c\u6cd5\u8bed\u52a9\u624b\u300d\u6cd5\u6c49-\u6c49\u6cd5\u8bcd\u5178 \u4e3a\u60a8\u63d0...",
#           "url":
#       "http://www.baidu.com/link?url=gf8WQbCMG49kYq7QMh9yk-o3s_xjgcTGE5JfoACclzEJsNG_OuriuR17goxMJs9L-yB8IqxmzGyfSh
#       cwKKScObTAvwUK9EV-zXcylpjqBfm",
#           "abstract": "\u5fae\u4e4e\u5176\u5fae\u7684\u89e3\u91ca\u548c\u53d1\u97f3
#       \u300c\u6cd5\u8bed\u52a9\u624b\u300d\u6cd5\u6c49-\u6c49\u6cd5\u8bcd\u5178 \u4e3a\u60a8\u63d0...Bien entendu,
#       les progr\u00e8s r\u00e9alis\u00e9s ont \u00e9t\u00e9 mineurs et le probl\u00e8me a m\u00eame empir\u00e9.
#       \u4e0d\u5fc5\u8bf4, \u65b9\u9762\u8fdb\u5c55
#       ,\u95ee\u9898\u5df2\u7ecf\u53d8\u5f97\u66f4\u52a0\u4e25\u91cd\u3002 Elle a recueilli peu de
#       soutien...\u897f\u8bed\u52a9\u624b\ue62b",
#           "rank": "2"
#         },
#         {
#           "title": "2015\u5e74\u6cd5\u8bed\u4e13\u4e1a\u516b\u7ea7\u8003\u8bd5\u771f\u9898 -
#       \u767e\u5ea6\u6587\u5e93",
#           "url":
#       "http://www.baidu.com/link?url=fhVt0r6UxolBhnKeohMFbQGeGMxcInwE9ze4yHy7rP2mhooE4WTOJwWF0dwGD2CgouclDMLF94Yxvs
#       i4m3edSK",
#           "abstract": "2015\u5e74\u6cd5\u8bed\u4e13\u4e1a\u516b\u7ea7\u8003\u8bd5\u771f\u9898 -
#       \u767e\u5ea6\u6587\u5e932015\u5e7411\u670825\u65e5  30. Le sporswear, arriv\u00e9 en France dans les
#       ann\u00e9es 1970 avec jogging, a influenc\u00e9 tous les secteurs vestimentaires sans exception et continue
#       de...\u767e\u5ea6\u6587\u5e93\ue62b",
#           "rank": "3"
#         },
#         {
#           "title":
#       "\u5b81\u6ce2\u5927\u5b66\u8003\u7814\u8f85\u5bfc\u73ed:2020\u5e74\u5b81\u6ce2\u5927\u5b66\u7855\u58eb\u7814\
#       u7a76\u751f\u8003\u8bd5\u771f\u9898\u4e4b2...",
#           "url":
#       "http://www.baidu.com/link?url=wz_RxTyjjkxwmWsKst53L4HFpEh7HQo3FpVGVjXbpVCWBSxXHmL7qHaZFezMB1PqxG91SQWSUqYBeY
#       aoG7Cbg_",
#           "abstract":
#       "\u5b81\u6ce2\u5927\u5b66\u8003\u7814\u8f85\u5bfc\u73ed:2020\u5e74\u5b81\u6ce2\u5927\u5b66\u7855\u58eb\u7814\
#       u7a76\u751f\u8003\u8bd5\u771f\u9898\u4e4b2...\n\n\n\n\n\n\n\n\n2021\u5e749\u67082\u65e5  I. Remplissez les
#       blancs en choisissant la bonne r\u00e9ponse (20 points).
#       \u8bf7\u9009\u62e9\u5408\u9002\u7684\u7b54\u6848\u586b\u7a7a(1\u5206x20=20\u5206)\u3002 1. Nos amis normands
#       habitent dans ___ charmant petit vi...\u65b0\u7965\u65ed\u8003\u7814\u5b98\u7f51\ue62b",
#           "rank": "4"
#         },
#         {
#           "title": "\u5305\u542bprogr\u00e8s \u7684\u6cd5\u8bed\u4f8b\u53e5 | \u6cd5\u8bed\u52a9\u624b
#       \u4f8b\u53e5\u8bcd\u5178",
#           "url":
#       "http://www.baidu.com/link?url=tSO6d2k69z_tVQa-BzgmkVIHpSWA_DFoduGqQWIpVDTWqijf33Uz2XNWKJyL_emuHXRQVAKKA5sTcX
#       tgcFkCbq",
#           "abstract": "\u5305\u542bprogr\u00e8s \u7684\u6cd5\u8bed\u4f8b\u53e5 | \u6cd5\u8bed\u52a9\u624b
#       \u4f8b\u53e5\u8bcd\u51782025\u5e743\u670815\u65e5  13.Avec l\u2019aide de son ami fran\u00e7ais, il a fait
#       beaucoup deprogr\u00e8s.
#       13.\u5728\u6cd5\u56fd\u670b\u53cb\u7684\u5e2e\u52a9\u4e0b,\u4ed6\u53d6\u5f97\u4e86\u5f88\u5927\u8fdb\u6b65\u3
#       002 \u8bc4\u4ef7\u8be5\u4f8b\u53e5:\u597d\u8bc4\u5dee\u8bc4\u6307\u6b63 14.Il a fait
#       d...\u6cd5\u8bed\u52a9\u624b\ue62b",
#           "rank": "5"
#         },
#         {
#           "title": "\u94bb\u63a2\u7684\u7684\u89e3\u91ca\u548c\u53d1\u97f3
#       \u300c\u6cd5\u8bed\u52a9\u624b\u300d\u6cd5\u6c49-\u6c49\u6cd5\u8bcd\u5178 \u4e3a\u60a8\u63d0\u4f9b...",
#           "url":
#       "http://www.baidu.com/link?url=5lPDl5j-fJ0pJvBSpRe8Vp-UAj76qlFokQCbsx1-uQxmEl-c_xrcR15cfhKUCLlFqdfaqame_vI35G
#       H8m_a2uLByVrrsz_FuBIEndxcxuaa",
#           "abstract": "\u94bb\u63a2\u7684\u7684\u89e3\u91ca\u548c\u53d1\u97f3
#       \u300c\u6cd5\u8bed\u52a9\u624b\u300d\u6cd5\u6c49-\u6c49\u6cd5\u8bcd\u5178 \u4e3a\u60a8\u63d0\u4f9b...Les
#       r\u00e9sultats de la derni\u00e8re campagne des forages en mer ont permis de lever les incertitudes
#       g\u00e9ologiques relatives \u00e0 la partie centrale du trac\u00e9 sous-marin
#       ...\u5fb7\u8bed\u52a9\u624b\ue62b",
#           "rank": "6"
#         }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        0.9057s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG ======================== assistant =========================
# DEBUG ### Top 3 Web Results for: latest advancements in AI
#
#       I was unable to retrieve sufficient results in English and French that specifically addressed the "latest
#       advancements in AI". The search results were either not relevant or in a different language. I will use
#       duckduckgo to attempt the query.
# DEBUG Tool Calls:
#           Name: 'duckduckgo_search'
#           Arguments: 'max_results: 3, query: latest advancements in AI'
#           Name: 'duckduckgo_search'
#           Arguments: 'max_results: 3, query: derniers progrès en IA'
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=7886, output=86, total=7972
# DEBUG * Time:                        1.0703s
# DEBUG * Tokens per second:           80.3493 tokens/s
# DEBUG ************************  METRICS  *************************
# DEBUG Getting function duckduckgo_search
# DEBUG Getting function duckduckgo_search
# DEBUG Running: duckduckgo_search(max_results=3, query=latest advancements in AI)
# DEBUG Searching DDG for: latest advancements in AI
# DEBUG Running: duckduckgo_search(max_results=3, query=derniers progrès en IA)
# DEBUG Searching DDG for: derniers progrès en IA
# DEBUG =========================== tool ===========================
# DEBUG [
#         {
#           "title": "Breaking News: The Biggest AI Advances of 2025 - SourceForge",
#           "href":
#       "https://sourceforge.net/articles/breaking-news-biggest-ai-advances-2025-heres-what-you-need-to-know/",
#           "body": "In summary, the last month in AI has been extraordinarily eventful.We've seen major model
#       advances (from Google's Gemini to Meta's Llama 4, Anthropic's Claude upgrades, Grok 3's new API, and the
#       release of OpenAI's GPT-4.1 models) that push the envelope of what AI can do. We've witnessed key product
#       improvements bringing AI further into mainstream apps (search, productivity tools ..."
#         },
#         {
#           "title": "The Top Artificial Intelligence Trends - IBM",
#           "href": "https://www.ibm.com/think/insights/artificial-intelligence-trends",
#           "body": "Learn how generative AI will evolve in 2024, from multimodal models to open source advancements,
#       GPU shortages and regulation. Discover the most important AI trends for enterprises and end users, and how
#       IBM can help you integrate AI into your workflows."
#         },
#         {
#           "title": "AI Index 2025: State of AI in 10 Charts | Stanford HAI",
#           "href": "https://hai.stanford.edu/news/ai-index-2025-state-of-ai-in-10-charts",
#           "body": "The new AI Index Report shows a maturing field, improvements in AI optimization, and a growing
#       saturation of use - and abuse - of this technology. The 2025 AI Index Report , published on April 7, 2025, is
#       an independent initiative at the Stanford Institute for Human-Centered Artificial Intelligence (HAI), led by
#       the AI Index Steering Committee ..."
#         }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        1.1224s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG =========================== tool ===========================
# DEBUG [
#         {
#           "title": "L'\u00e9tat de l'IA en 2025 : principaux enseignements du dernier rapport de ...",
#           "href":
#       "https://www.unite.ai/fr/L'\u00e9tat-de-l'IA-en-2025-:-principaux-points-\u00e0-retenir-du-dernier-rapport-de
#       -Stanford-sur-l'indice-de-l'IA/",
#           "body": "Le rapport souligne que l'IA a r\u00e9alis\u00e9 des progr\u00e8s techniques extraordinaires en
#       termes de performances et de capacit\u00e9s au cours de l'ann\u00e9e \u00e9coul\u00e9e. Par exemple, les
#       mod\u00e8les ont enregistr\u00e9 une augmentation de performance allant jusqu'\u00e0 67 % dans les nouveaux
#       benchmarks tels que MMLU, GPQA ..."
#         },
#         {
#           "title": "Actu.ai : Derni\u00e8res Actualit\u00e9s et Tendances en Intelligence Artificielle",
#           "href": "https://actu.ai/",
#           "body": "Nous vous informons sur les derni\u00e8res actualit\u00e9s, innovations et tendances dans le
#       monde de l'intelligence artificielle sur Actu.ai. Restez \u00e0 jour sur les d\u00e9veloppements cl\u00e9s en
#       IA, \u00e9thique, technologies \u00e9mergentes et plus encore ..."
#         },
#         {
#           "title": "La r\u00e9volution de l'intelligence artificielle : Jusqu'o\u00f9 ira le progr\u00e8s ...",
#           "href":
#       "https://www.oddo-bhf.com/fr/2025/04/16/la-revolution-de-lintelligence-artificielle-jusquou-ira-le-progres/",
#           "body": "LA COURSE continue ! Ces derni\u00e8res ann\u00e9es ont \u00e9t\u00e9 tout simplement
#       extraordinaires pour l'intelligence artificielle. Depuis le lancement de ChatGPT \u00e0 la fin de
#       l'ann\u00e9e 2022, les progr\u00e8s se sont encha\u00een\u00e9s \u00e0 un rythme
#       effr\u00e9n\u00e9.Aujourd'hui, des mod\u00e8les comme Grok 3, GPT-4o et DeepSeek R1 sont bien plus puissants
#       que leurs pr\u00e9d\u00e9cesseurs et \u00e9voluent de mani\u00e8re exponentielle."
#         }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        1.1530s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG ======================== assistant =========================
# DEBUG ### Top 6 Web Results for: latest advancements in AI
#
#       #### English Source 1
#       - **Title:** Breaking News: The Biggest AI Advances of 2025 - SourceForge
#       - **Summary:** This article discusses the rapid advancements in AI, mentioning model improvements from
#       Google's Gemini to Meta's Llama 4, Anthropic's Claude upgrades, Grok 3's new API, and the release of OpenAI's
#       GPT-4.1 models. It highlights that these advancements are pushing the boundaries of what AI can achieve.
#       - **Link:**
#       https://sourceforge.net/articles/breaking-news-biggest-ai-advances-2025-heres-what-you-need-to-know/
#       - **Language:** English
#
#       #### English Source 2
#       - **Title:** The Top Artificial Intelligence Trends - IBM
#       - **Summary:** The article focuses on how generative AI is evolving in 2024, covering multimodal models,
#       open-source advancements, GPU shortages, and regulatory aspects. It aims to provide insights into the most
#       significant AI trends for enterprises and end-users, along with how IBM can assist in integrating AI into
#       workflows.
#       - **Link:** https://www.ibm.com/think/insights/artificial-intelligence-trends
#       - **Language:** English
#
#       #### English Source 3
#       - **Title:** AI Index 2025: State of AI in 10 Charts | Stanford HAI
#       - **Summary:** This report, published on April 7, 2025, by Stanford HAI, highlights a maturing AI field. It
#       shows improvements in AI optimization, alongside a growing saturation in the use and potential misuse of the
#       technology.
#       - **Link:** https://hai.stanford.edu/news/ai-index-2025-state-of-ai-in-10-charts
#       - **Language:** English
#
#       #### French Source 1
#       - **Title:** L'état de l'IA en 2025 : principaux enseignements du dernier rapport de ...
#       - **Summary:** This article discusses the extraordinary technical progress made by AI in terms of performance
#       and capabilities over the past year. It mentions that models have seen performance increases of up to 67% in
#       new benchmarks.
#       - **Link:**
#       https://www.unite.ai/fr/L'état-de-l'IA-en-2025-:-principaux-points-à-retenir-du-dernier-rapport-de-Stanford-s
#       ur-l'indice-de-l'IA/
#       - **Language:** French
#
#       #### French Source 2
#       - **Title:** Actu.ai : Dernières Actualités et Tendances en Intelligence Artificielle
#       - **Summary:** Actu.ai provides the latest news, innovations, and trends in the world of artificial
#       intelligence. The portal keeps users updated on key developments in AI, ethics, emerging technologies, and
#       more.
#       - **Link:** https://actu.ai/
#       - **Language:** French
#
#       #### French Source 3
#       - **Title:** La révolution de l'intelligence artificielle : Jusqu'où ira le progrès ...
#       - **Summary:** This article highlights the extraordinary progress in AI in recent years, especially since the
#       launch of ChatGPT in late 2022. It notes that models like Grok 3, GPT-4o, and DeepSeek R1 are significantly
#       more powerful than their predecessors and are evolving exponentially.
#       - **Link:**
#       https://www.oddo-bhf.com/fr/2025/04/16/la-revolution-de-lintelligence-artificielle-jusquou-ira-le-progres/
#       - **Language:** French
#
#       ### Observations
#       - Both English and French sources emphasize the rapid advancements in AI, particularly in generative models
#       and their increasing capabilities.
#       - The English sources highlight specific model improvements and reports on the state of AI, while the French
#       sources also focus on the pace of progress and the impact of models like ChatGPT.
#       - There is a consensus across both languages regarding the significant strides made in AI and its growing
#       influence across various sectors.
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=9073, output=875, total=9948
# DEBUG * Time:                        4.5580s
# DEBUG * Tokens per second:           191.9717 tokens/s
# DEBUG ************************  METRICS  *************************
# DEBUG ------------------- Google Response End --------------------
# DEBUG Added 6 Messages to AgentMemory
# DEBUG Added AgentRun to AgentMemory
# DEBUG Logging Agent Run
# DEBUG *** Agent Run End: aaef1862-11ab-41cd-970e-102f7a96b83a ****
# ### Top 3 Web Results for: latest advancements in AI
#
# I was unable to retrieve sufficient results in English and French that specifically addressed the "latest advancements in AI". The search results were either not relevant or in a different language. I will use duckduckgo to attempt the query.
#
# ### Top 6 Web Results for: latest advancements in AI
#
# #### English Source 1
# - **Title:** Breaking News: The Biggest AI Advances of 2025 - SourceForge
# - **Summary:** This article discusses the rapid advancements in AI, mentioning model improvements from Google's Gemini to Meta's Llama 4, Anthropic's Claude upgrades, Grok 3's new API, and the release of OpenAI's GPT-4.1 models. It highlights that these advancements are pushing the boundaries of what AI can achieve.
# - **Link:** https://sourceforge.net/articles/breaking-news-biggest-ai-advances-2025-heres-what-you-need-to-know/
# - **Language:** English
#
# #### English Source 2
# - **Title:** The Top Artificial Intelligence Trends - IBM
# - **Summary:** The article focuses on how generative AI is evolving in 2024, covering multimodal models, open-source advancements, GPU shortages, and regulatory aspects. It aims to provide insights into the most significant AI trends for enterprises and end-users, along with how IBM can assist in integrating AI into workflows.
# - **Link:** https://www.ibm.com/think/insights/artificial-intelligence-trends
# - **Language:** English
#
# #### English Source 3
# - **Title:** AI Index 2025: State of AI in 10 Charts | Stanford HAI
# - **Summary:** This report, published on April 7, 2025, by Stanford HAI, highlights a maturing AI field. It shows improvements in AI optimization, alongside a growing saturation in the use and potential misuse of the technology.
# - **Link:** https://hai.stanford.edu/news/ai-index-2025-state-of-ai-in-10-charts
# - **Language:** English
#
# #### French Source 1
# - **Title:** L'état de l'IA en 2025 : principaux enseignements du dernier rapport de ...
# - **Summary:** This article discusses the extraordinary technical progress made by AI in terms of performance and capabilities over the past year. It mentions that models have seen performance increases of up to 67% in new benchmarks.
# - **Link:** https://www.unite.ai/fr/L'état-de-l'IA-en-2025-:-principaux-points-à-retenir-du-dernier-rapport-de-Stanford-sur-l'indice-de-l'IA/
# - **Language:** French
#
# #### French Source 2
# - **Title:** Actu.ai : Dernières Actualités et Tendances en Intelligence Artificielle
# - **Summary:** Actu.ai provides the latest news, innovations, and trends in the world of artificial intelligence. The portal keeps users updated on key developments in AI, ethics, emerging technologies, and more.
# - **Link:** https://actu.ai/
# - **Language:** French
#
# #### French Source 3
# - **Title:** La révolution de l'intelligence artificielle : Jusqu'où ira le progrès ...
# - **Summary:** This article highlights the extraordinary progress in AI in recent years, especially since the launch of ChatGPT in late 2022. It notes that models like Grok 3, GPT-4o, and DeepSeek R1 are significantly more powerful than their predecessors and are evolving exponentially.
# - **Link:** https://www.oddo-bhf.com/fr/2025/04/16/la-revolution-de-lintelligence-artificielle-jusquou-ira-le-progres/
# - **Language:** French
#
# ### Observations
# - Both English and French sources emphasize the rapid advancements in AI, particularly in generative models and their increasing capabilities.
# - The English sources highlight specific model improvements and reports on the state of AI, while the French sources also focus on the pace of progress and the impact of models like ChatGPT.
# - There is a consensus across both languages regarding the significant strides made in AI and its growing influence across various sectors.

# %%
# Agent to summarize viodeo content using YouTubeTools
# using OpenRouter model with API key
Video_agent_ = Agent(
    name="YouTube agent",
    model=Gemini(id="gemini-2.0-flash",
                     api_key="AIzaSyCiIkB8D_Y-utNrWKLDa8Aozlru4C4SpPE"), #OpenAIChat("gpt-4o"),
    role="YouTube agent",
    tools=[YouTubeTools()],
    show_tool_calls=False,
    debug_mode=False,
    description="You are a YouTube agent. Obtain the captions of a YouTube video and answer questions.",
    instructions=[
        """
    You are a specialized research assistant focused on extracting insights from YouTube video content. Your task is to watch the provided video, analyze its spoken content using captions, and summarize its core messages, findings, and methodologies when applicable.

Video Link: {video_url}  
Research Context: {topic}  
User Preferences: {preferences}  
Additional Instructions: {instructions}  

Instructions:
- Retrieve the **captions/transcript** from the YouTube video.
- Analyze the full content to understand the main topic, supporting arguments, and any technical or research-based methodologies discussed.
- Summarize the content in **clear, structured sections**:
  1. **Video Title**
  2. **Channel Name and Upload Date** (if available)
  3. **Summary of the content** (5–8 sentences)
  4. **Key points / findings**
  5. **Any cited tools, frameworks, or methodologies**
  6. **Link to the original video**

Additional Notes:
- Focus on **technical depth**, especially if the video is research-, AI-, or data-related.
- If the video is informal or lacks scientific content, summarize only the **main takeaways** clearly.
- Your language should remain professional and informative for researchers or analysts.
- Output your results in **Markdown format** for integration into research reports.

Final Output Example:

### YouTube Summary: {video_title}

- **Channel:** {channel_name}  
- **Published on:** {upload_date}  
- **Video Link:** {video_url}

#### Summary  
{summary_text}

#### Key Points  
- Point 1  
- Point 2  
- ...

#### Tools / Frameworks Mentioned  
- ...


"""
    ],
)

#Video_agent.print_response("Summarize this video https://www.youtube.com/watch?v=Iv9dewmcFbs&t", markdown=True)
#print(Video_agent_.run("Summarize this video https://www.youtube.com/watch?v=Iv9dewmcFbs&t").content)
print(Video_agent_.run("learn machine and deep learning").content)
# Out:
# Okay, I'm ready to help you learn about machine and deep learning. Please provide the link to the YouTube video you want me to analyze.

# %%
# Agent to search for trending discussions and real-time updates on LinkedIn
# using Gemini model with API key
linkedin_researcher = Agent(
    name="Linkedin Researcher",
    model=Gemini(id="gemini-2.0-flash",
                     api_key="AIzaSyCiIkB8D_Y-utNrWKLDa8Aozlru4C4SpPE"),
    role="Research trending discussions and real-time updates",
    tools=[DuckDuckGoTools()],
    add_name_to_instructions=True,
    instructions=dedent("""
    You are a professional research assistant focused on identifying **trending discussions**, **influential posts**, and **real-time insights** from LinkedIn and related platforms. Your goal is to investigate what professionals, experts, and companies are saying about a specific topic.

Research Topic: {topic}  
User Preferences: {preferences}  
Additional Instructions: {instructions}  

Your Responsibilities:
- Search for **LinkedIn-based discussions**, thought leadership posts, event announcements, and hashtag trends related to the given topic.
- Use DuckDuckGo (or equivalent) to find relevant LinkedIn links, posts, and commentary.
- Focus on:
  - **Verified or influential users** (e.g., industry leaders, researchers, executives)
  - **Company posts** and product announcements
  - **Trending hashtags** and ongoing professional conversations
- Avoid low-engagement or outdated posts.

For each relevant finding, provide:
  1. **Post Author / Company**
  2. **Date of the post or discussion**
  3. **Summary of what was said** (2–4 sentences)
  4. **Relevant hashtags (if present)**
  5. **Direct link to the post**

Output Format:
- Structured in Markdown for easy integration with research summaries
- Group findings by user/company or hashtag where applicable
- Highlight any themes, controversies, or innovations being discussed

Final Output Example:

### LinkedIn Trends: {topic}

#### Author: John Doe (AI Strategist @ Google)  
- **Date:** March 2025  
- **Summary:** Discussed the ethical implications of generative AI in recruiting. Highlights concerns around bias in algorithmic hiring.  
- **Hashtags:** #GenerativeAI #FutureOfWork  
- **Link:** [LinkedIn Post](https://www.linkedin.com/...)

#### Company: NVIDIA  
- **Date:** April 2025  
- **Summary:** Announced a collaboration with Hugging Face for AI chip optimization.  
- **Hashtags:** #AIHardware #NVIDIA  
- **Link:** [Company Post](https://www.linkedin.com/...)

### Observations  
- Frequent mentions of ethical AI and regulatory concerns  
- Top influencers include {names}, primarily from {industries}  
- Notable growth in hashtag activity around {emerging trend}

    """),
    show_tool_calls=True,
    debug_mode=True,
)
print(linkedin_researcher.run("What are the latest advancements in gen-AI?").content)
# Out:
# DEBUG ****** Agent ID: 7d7e0b18-ea46-47eb-a483-827cc44afb60 ******
# DEBUG ***** Session ID: ddd539eb-b1dc-4446-9b7e-b827509f8ca7 *****
# DEBUG ** Agent Run Start: 63ae12ae-7451-4b40-ac5a-3c8d63091ddd ***
# DEBUG Processing tools for model
# DEBUG Added function duckduckgo_search from duckduckgo
# DEBUG Added function duckduckgo_news from duckduckgo
# DEBUG ------------------ Google Response Start -------------------
# DEBUG ----------------- Model: gemini-2.0-flash ------------------
# DEBUG ========================== system ==========================
# DEBUG <your_role>
#       Research trending discussions and real-time updates
#       </your_role>
#
#       <instructions>
#
#           You are a professional research assistant focused on identifying **trending discussions**, **influential
#       posts**, and **real-time insights** from LinkedIn and related platforms. Your goal is to investigate what
#       professionals, experts, and companies are saying about a specific topic.
#
#       Research Topic: {topic}
#       User Preferences: {preferences}
#       Additional Instructions: {instructions}
#
#       Your Responsibilities:
#       - Search for **LinkedIn-based discussions**, thought leadership posts, event announcements, and hashtag
#       trends related to the given topic.
#       - Use DuckDuckGo (or equivalent) to find relevant LinkedIn links, posts, and commentary.
#       - Focus on:
#         - **Verified or influential users** (e.g., industry leaders, researchers, executives)
#         - **Company posts** and product announcements
#         - **Trending hashtags** and ongoing professional conversations
#       - Avoid low-engagement or outdated posts.
#
#       For each relevant finding, provide:
#         1. **Post Author / Company**
#         2. **Date of the post or discussion**
#         3. **Summary of what was said** (2–4 sentences)
#         4. **Relevant hashtags (if present)**
#         5. **Direct link to the post**
#
#       Output Format:
#       - Structured in Markdown for easy integration with research summaries
#       - Group findings by user/company or hashtag where applicable
#       - Highlight any themes, controversies, or innovations being discussed
#
#       Final Output Example:
#
#       ### LinkedIn Trends: {topic}
#
#       #### Author: John Doe (AI Strategist @ Google)
#       - **Date:** March 2025
#       - **Summary:** Discussed the ethical implications of generative AI in recruiting. Highlights concerns around
#       bias in algorithmic hiring.
#       - **Hashtags:** #GenerativeAI #FutureOfWork
#       - **Link:** [LinkedIn Post](https://www.linkedin.com/...)
#
#       #### Company: NVIDIA
#       - **Date:** April 2025
#       - **Summary:** Announced a collaboration with Hugging Face for AI chip optimization.
#       - **Hashtags:** #AIHardware #NVIDIA
#       - **Link:** [Company Post](https://www.linkedin.com/...)
#
#       ### Observations
#       - Frequent mentions of ethical AI and regulatory concerns
#       - Top influencers include {names}, primarily from {industries}
#       - Notable growth in hashtag activity around {emerging trend}
#
#
#       </instructions>
#
#       <additional_information>
#       - Your name is: Linkedin Researcher.
#       </additional_information>
# DEBUG =========================== user ===========================
# DEBUG What are the latest advancements in gen-AI?
# DEBUG ======================== assistant =========================
# DEBUG Tool Calls:
#           Name: 'duckduckgo_search'
#           Arguments: 'query: LinkedIn gen-AI advancements, max_results: 5'
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=649, output=14, total=663
# DEBUG * Time:                        1.2911s
# DEBUG * Tokens per second:           10.8432 tokens/s
# DEBUG ************************  METRICS  *************************
# DEBUG Getting function duckduckgo_search
# DEBUG Running: duckduckgo_search(query=LinkedIn gen-AI advancements, max_results=5)
# DEBUG Searching DDG for: LinkedIn gen-AI advancements
# DEBUG =========================== tool ===========================
# DEBUG [
#         {
#           "title": "Career Essentials in Generative AI by Microsoft and LinkedIn",
#           "href":
#       "https://www.linkedin.com/learning/paths/career-essentials-in-generative-ai-by-microsoft-and-linkedin",
#           "body": "Discover the skills needed to apply generative AI in your career. Learn the core concepts of
#       artificial intelligence and generative AI functionality."
#         },
#         {
#           "title": "Roundup: Latest in Gen AI Advancements by Tech ... - LinkedIn",
#           "href":
#       "https://www.linkedin.com/pulse/roundup-latest-gen-ai-advancements-tech-giants-teamepic-ai-bqetc/",
#           "body": "DTP #34: Gen AI Is Making Companies More Data Oriented We've compiled the latest advancements in
#       Gen AI tech and how prominent organizations are putting them to use below. Quick summary ..."
#         },
#         {
#           "title": "Exploring GEN AI: The Future of Artificial Intelligence - LinkedIn",
#           "href":
#       "https://www.linkedin.com/pulse/exploring-gen-ai-future-artificial-intelligence-teja-karthik-6yfxc",
#           "body": "GEN AI represents the future of artificial intelligence, with the potential to revolutionize
#       industries, improve human life, and transform how we interact with machines."
#         },
#         {
#           "title": "Top 6 Generative AI advancements at Google Cloud - LinkedIn",
#           "href":
#       "https://www.linkedin.com/posts/naveenbalani_101-real-world-gen-ai-use-cases-from-the-activity-71855996046026
#       62913-O55G",
#           "body": "Here are 101 \"real-world\" gen AI use cases from industry leaders. All using Google's cutting
#       edge AI capabilities to transform their businesses. https://lnkd.in/gVSbrGnu Google #GenAI"
#         },
#         {
#           "title": "Association of Data Scientists on LinkedIn: 6 Most Exciting ...",
#           "href":
#       "https://www.linkedin.com/posts/association-of-data-scientists_6-most-exciting-advancements-in-gen-ai-activit
#       y-7188419930394955776-gE2R",
#           "body": "Generative AI has been making rapid strides, with a series of groundbreaking advancements that
#       are transforming how we interact with technology. Here are 6 of the most exciting developments in ..."
#         }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        0.9401s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG ======================== assistant =========================
# DEBUG ### LinkedIn Trends: gen-AI Advancements
#
#       #### LinkedIn Learning
#       - **Date:** N/A
#       - **Summary:** Offers a learning path to discover the skills needed to apply generative AI in your career,
#       covering core concepts of AI and generative AI functionality.
#       - **Hashtags:** N/A
#       - **Link:** [LinkedIn
#       Post](https://www.linkedin.com/learning/paths/career-essentials-in-generative-ai-by-microsoft-and-linkedin)
#
#       #### Teamepic.ai
#       - **Date:** N/A
#       - **Summary:** Provides a roundup of the latest advancements in GenAI tech and how prominent organizations
#       are utilizing them, emphasizing GenAI's role in making companies more data-oriented.
#       - **Hashtags:** N/A
#       - **Link:** [LinkedIn
#       Post](https://www.linkedin.com/pulse/roundup-latest-gen-ai-advancements-tech-giants-teamepic-ai-bqetc/)
#
#       #### Teja Karthik
#       - **Date:** N/A
#       - **Summary:** Highlights that GEN AI represents the future of artificial intelligence and its potential to
#       revolutionize industries, improve human life, and transform human-machine interaction.
#       - **Hashtags:** N/A
#       - **Link:** [LinkedIn
#       Post](https://www.linkedin.com/pulse/exploring-gen-ai-future-artificial-intelligence-teja-karthik-6yfxc)
#
#       #### Naveen Balani (Google Cloud)
#       - **Date:** N/A
#       - **Summary:** Shares 101 real-world gen AI use cases from industry leaders using Google's AI capabilities to
#       transform their businesses.
#       - **Hashtags:** #GenAI
#       - **Link:** [LinkedIn
#       Post](https://www.linkedin.com/posts/naveenbalani_101-real-world-gen-ai-use-cases-from-the-activity-718559960
#       4602662913-O55G)
#
#       #### Association of Data Scientists
#       - **Date:** N/A
#       - **Summary:** Lists 6 of the most exciting developments in Generative AI that are transforming how we
#       interact with technology.
#       - **Hashtags:** N/A
#       - **Link:** [LinkedIn
#       Post](https://www.linkedin.com/posts/association-of-data-scientists_6-most-exciting-advancements-in-gen-ai-ac
#       tivity-7188419930394955776-gE2R)
#
#       ### Observations
#       - A lot of the posts do not have specific dates.
#       - It focuses on use cases of gen-AI, and how it is being implemented by tech companies.
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=1258, output=597, total=1855
# DEBUG * Time:                        3.0414s
# DEBUG * Tokens per second:           196.2905 tokens/s
# DEBUG ************************  METRICS  *************************
# DEBUG ------------------- Google Response End --------------------
# DEBUG Added 4 Messages to AgentMemory
# DEBUG Added AgentRun to AgentMemory
# DEBUG Logging Agent Run
# DEBUG *** Agent Run End: 63ae12ae-7451-4b40-ac5a-3c8d63091ddd ****
# ### LinkedIn Trends: gen-AI Advancements
#
# #### LinkedIn Learning
# - **Date:** N/A
# - **Summary:** Offers a learning path to discover the skills needed to apply generative AI in your career, covering core concepts of AI and generative AI functionality.
# - **Hashtags:** N/A
# - **Link:** [LinkedIn Post](https://www.linkedin.com/learning/paths/career-essentials-in-generative-ai-by-microsoft-and-linkedin)
#
# #### Teamepic.ai
# - **Date:** N/A
# - **Summary:** Provides a roundup of the latest advancements in GenAI tech and how prominent organizations are utilizing them, emphasizing GenAI's role in making companies more data-oriented.
# - **Hashtags:** N/A
# - **Link:** [LinkedIn Post](https://www.linkedin.com/pulse/roundup-latest-gen-ai-advancements-tech-giants-teamepic-ai-bqetc/)
#
# #### Teja Karthik
# - **Date:** N/A
# - **Summary:** Highlights that GEN AI represents the future of artificial intelligence and its potential to revolutionize industries, improve human life, and transform human-machine interaction.
# - **Hashtags:** N/A
# - **Link:** [LinkedIn Post](https://www.linkedin.com/pulse/exploring-gen-ai-future-artificial-intelligence-teja-karthik-6yfxc)
#
# #### Naveen Balani (Google Cloud)
# - **Date:** N/A
# - **Summary:** Shares 101 real-world gen AI use cases from industry leaders using Google's AI capabilities to transform their businesses.
# - **Hashtags:** #GenAI
# - **Link:** [LinkedIn Post](https://www.linkedin.com/posts/naveenbalani_101-real-world-gen-ai-use-cases-from-the-activity-7185599604602662913-O55G)
#
# #### Association of Data Scientists
# - **Date:** N/A
# - **Summary:** Lists 6 of the most exciting developments in Generative AI that are transforming how we interact with technology.
# - **Hashtags:** N/A
# - **Link:** [LinkedIn Post](https://www.linkedin.com/posts/association-of-data-scientists_6-most-exciting-advancements-in-gen-ai-activity-7188419930394955776-gE2R)
#
# ### Observations
# - A lot of the posts do not have specific dates.
# - It focuses on use cases of gen-AI, and how it is being implemented by tech companies.

# %%
# Team Manager to manage the agents and their interactions
# using OpenRouter model with API key
manager_team_ = Team(
    name="Repporter Team",
    mode="collaborate",
    model=Gemini(id="gemini-2.0-flash",
                     api_key="AIzaSyCiIkB8D_Y-utNrWKLDa8Aozlru4C4SpPE"), 
    members=[
        engine_search_agent_,
        academic_paper_researcher_,
        linkedin_researcher,
        Video_agent_,
    ],
    instructions=[
        """You are the intelligent coordinator of a multi-agent research team tasked with generating a **comprehensive, structured scientific and technical report** based on contributions from multiple expert agents. Each agent specializes in a distinct research channel (web, academic, social, video) and works under your strategic guidance.

Research Topic: {topic}  
User Preferences: {preferences}  
Additional Instructions: {instructions}  

Your Team:
- **Academic Paper Researcher:** Finds peer-reviewed articles and summarizes academic methodologies and results  
- **Search Engine Agent:** Gathers the latest web-based news, updates, and articles related to the topic  
- **Video Agent:** Analyzes and summarizes technical YouTube content related to the topic  
- **LinkedIn Researcher:** Identifies real-time discussions, thought leaders, and trends from the professional sphere  

Your Responsibilities:
1. Assign subtasks to each agent and **track their progress**
2. Ensure every agent responds with **clear, non-redundant**, and **source-backed content**
3. Synthesize their outputs into a **final report** that includes the following sections:
    - **Introduction** (purpose and scope)
    - **Literature Review** (by Academic Paper Researcher)
    - **Web Insights & Trends** (by Search Engine Agent)
    - **Multimedia Analysis** (by Video Agent)
    - **Professional and Social Commentary** (by LinkedIn Researcher)
    - **Synthesis & Cross-Analysis**
    - **Conclusions & Recommendations**

4. Add:
    - Source links and citations
    - Consistent formatting and tone
    - Lists, highlights, and headings for clarity
    - Markdown structure for export

Constraints & Quality Rules:
- Avoid overlap or contradiction between agents’ sections
- Identify **recurring themes**, **gaps**, and **new opportunities**
- Ensure findings are **evidence-based**, professional, and insightful
- Be explicit about any divergence or uncertainty in findings

✅ **Final Output Format:** Markdown  
📈 **Goal:** Deliver a multi-perspective report that helps researchers, analysts, or executives rapidly grasp the state of the topic.

---

### 🧪 Example Final Output (for a topic like "Advancements in Generative AI"):

```markdown
# Scientific-Technical Report: Advancements in Generative AI

## Introduction  
...

## Literature Review  
...

## Web Trends & Industry Insights  
...

## YouTube Multimedia Insights  
...

## Professional Commentary (LinkedIn)  
...

## Synthesis & Key Observations  
...

## Final Conclusions & Recommendations  
...


"""
    ],
    success_criteria="""Success Criteria:
- All agents contribute their findings on time
- The report is coherent, well-cited, and integrates all modalities
- The team agrees on conclusions or clearly notes discrepancies""",
    enable_agentic_context=True,
    show_tool_calls=False,
    markdown=True,
    show_members_responses=True,
    debug_mode=False,
)

import nest_asyncio
nest_asyncio.apply()

async def main():
    manager_team_.print_response(
        message="Start the repport on the topic: 'what is the best lightweight large language models for generating questions from a user query?'",
        stream=True,
        stream_intermediate_steps=True,
    )

if __name__ == "__main__":
    import asyncio
    asyncio.get_event_loop().run_until_complete(main())
# Out:
# DEBUG ***** Session ID: af1af359-4fa2-4266-972d-e54523bf4602 *****
# Output()
# DEBUG ****** Agent ID: 7acc9dde-a2fd-4780-8935-210a97722bdd ******
# DEBUG ***** Session ID: b38035a4-c4a0-4c6e-a08c-30675773ff02 *****
# DEBUG ** Agent Run Start: 955fab8c-88b1-4205-9a14-a835b55b975d ***
# DEBUG --------------- Google Response Stream Start ---------------
# DEBUG ----------------- Model: gemini-2.0-flash ------------------
# DEBUG ========================== system ==========================
# DEBUG You are a search agent that helps users find the most relevant information using Baidu.
#
#       <your_role>
#       Research academic papers and scholarly content
#       </your_role>
#
#       <instructions>
#       You are a multilingual search agent with expertise in discovering relevant information from the web using
#       Baidu. You are tasked with retrieving the most accurate and informative web-based content related to a given
#       research topic.
#
#       Research Topic: {topic}
#       Research Preferences: {preferences}
#       Additional Instructions: {instructions}
#
#       Instructions:
#       - Search using **both English and French queries** to capture a broader and more diverse range of sources.
#       - Retrieve **at least 5 search results**, then **select the 6 most relevant and unique** entries.
#       - For each selected result, provide:
#         1. **Title of the page or article**
#         2. **A short summary (2–4 sentences)** explaining the main idea and relevance
#         3. **The direct link** to the page
#         4. **Language of the source** (e.g., English / French )
#
#       Output Format:
#       - Present the 3 final results in a clean and structured Markdown format.
#       - Separate English and French sources for clarity, if applicable.
#       - If duplicate or low-quality results are found, discard them and choose better alternatives.
#       - Do not include advertisements, low-quality blogs, or irrelevant pages.
#
#       Final Output Example:
#
#       ### Top 3 Web Results for: {topic}
#
#       #### English Source 1
#       - **Title:** ...
#       - **Summary:** ...
#       - **Link:** ...
#       - **Language:** English
#
#       #### French Source 1
#       - **Title:** ...
#       - **Summary:** ...
#       - **Link:** ...
#       - **Language:** French
#
#       (...and so on...)
#
#       ### Observations
#       - Highlight any interesting differences between Chinese and English perspectives.
#       - Mention if certain subtopics are trending or widely discussed in either language.
#
#
#       </instructions>
#
#       <additional_information>
#       - Use markdown to format your answers.
#       </additional_information>
# DEBUG =========================== user ===========================
# DEBUG You are a member of a team of agents that collaborate to complete a task.
#
#       <task>
#       Research and provide information on the best lightweight large language models for generating questions from
#       a user query. Focus on models that are efficient in terms of computational resources and memory footprint.
#       </task>
#
#       <expected_output>
#       A list of lightweight LLMs suitable for question generation, along with their key features, performance
#       metrics, and use cases. Cite all sources.
#       </expected_output>
#
#       <team_context>
#       The research topic is 'what is the best lightweight large language models for generating questions from a
#       user query?'
#       </team_context>
# DEBUG ======================== assistant =========================
# DEBUG Tool Calls:
#           Name: 'baidu_search'
#           Arguments: 'max_results: 8, query: lightweight large language models question generation, language: en'
#           Name: 'baidu_search'
#           Arguments: 'language: fr, query: modèles de langage léger génération de questions, max_results: 8'
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=771, output=32, total=803
# DEBUG * Time:                        0.8156s
# DEBUG * Tokens per second:           39.2327 tokens/s
# DEBUG * Time to first token:         0.8083s
# DEBUG ************************  METRICS  *************************
# DEBUG Getting function baidu_search
# DEBUG Getting function baidu_search
# DEBUG Running: baidu_search(max_results=8, query=..., language=en)
# DEBUG Searching Baidu [en] for: lightweight large language models question generation
# DEBUG Running: baidu_search(language=fr, query=..., max_results=8)
# DEBUG Searching Baidu [fr] for: modèles de langage léger génération de questions
# DEBUG =========================== tool ===========================
# DEBUG [
#         {
#           "title": "\u767e\u5ea6\u7ffb\u8bd1",
#           "url":
#       "http://www.baidu.com/link?url=vWwpk6RhsGqbMcMjkh5b9CdsndQICxQ4eTd7X8vPbGBZtyCokdzF0pOZJOPCmCxiVtJgM1GRAHCFWX
#       m-NXgzdK8HyC4Zm6DfbGgLHI6AwSD3Wkt0Vi1cE0XfxnF6hZfgh-CR3NjytGpopyeJ_JJ5ZnPNceMsr9nuk9ugG0v1JcO",
#           "abstract":
#       "\u767e\u5ea6\u7ffb\u8bd1\n\n\u82f1\u8bed\ue73c\n\n\n\n\n\u4e2d\u6587\ue73c\n\n\n\n\n\n\n\n\n\n\n\ue601\n\n\n
#       0 / 2000\n                    \n\n\n\n\n\n\n\n
#       \u70b9\u51fb\u5212\u7ebf\u5355\u8bcd\u53ef\u67e5\u770b\u91ca\u4e49\n
#       \n\n\n\n\n\n\u8f7b\u91cf\u7ea7\u5927\u578b\u8bed\u8a00\u6a21\u578b\u95ee\u9898\u751f\u6210\n\n\n\n
#       \u590d\u5236\u6210\u529f\n
#       \n\n\n\n\n\n\ue6c2\n\n\n\n\u8bd5\u8bd5\u6587\u6863\u7ffb\u8bd1\u4e0b\u8f7d\u767e\u5ea6\u7ffb\u8bd1\u684c\u976
#       2\u7aef\u767e\u5ea6\u7ffb\u8bd1",
#           "rank": "1"
#         },
#         {
#           "title":
#       "\u5229\u7528\u5927\u6a21\u578b\u505a\u77e5\u8bc6\u68c0\u7d22\u65f6\u600e\u4e48\u63d0\u9ad8RAG\u7684\u6b63\u7
#       86e\u6027\u548c\u9c81\u68d2\u6027? - ...",
#           "url":
#       "http://www.baidu.com/link?url=vWwpk6RhsGqbMcMjkh5b9_2Icnx5P6gOvAKDEiwQWb05K8GVkZuBfJ3alC9N-gUWGUeinCp3YSgJ4j
#       dEC-wF5_",
#           "abstract":
#       "\u5229\u7528\u5927\u6a21\u578b\u505a\u77e5\u8bc6\u68c0\u7d22\u65f6\u600e\u4e48\u63d0\u9ad8RAG\u7684\u6b63\u7
#       86e\u6027\u548c\u9c81\u68d2\u6027? - ...\n\n\n\n\n\n\n\n\n2025\u5e742\u670810\u65e5  2. Take a Step Back:
#       Evoking Reasoning via Abstraction in Large Language Models \u8bba\u6587\u5730\u5740:arxiv.org/abs/2310.0611
#       \u8ba9LLM\u62bd\u8c61\u4e00\u5c42\u3001\u5728\u66f4\u9ad8level\u4e0a\u601d\u8003,\u4f7f\u5f97\u63a8\u7406\u8f
#       c7\u7a0b\u66f4\u51c6...\n\n\n\n\n\u77e5\u4e4e\ue62b",
#           "rank": "2"
#         },
#         {
#           "title": "Investigating Large Language Models for Prompt... - \u767e\u5ea6\u5b66\u672f",
#           "url":
#       "http://www.baidu.com/link?url=YLZ1wMrolzvIhBHYMs-cZmivKPWpHrFeZfd3v3NnOFVQ1eEM9hQbpFipmmzt8hR1a4v9pP6FJDttZF
#       sK2ESg-EOECE3C89YcBzqN5BbLn72fa2zQvXnXe4Evtojjd5SpZg5gHAbs5LI0vJfBweDkc1FhxjvjnAoRwVQKvHVdW1OL1ykVreC9zGssA8b
#       2GAIqrjjtWv4AQ-UHfyYnX0gF9TuI6xPdEpiw739eHZGy6U5LXCgojJaoRkAZ7zP0bdD7uwpVmVodLzgKyzYCad6JgbYHfa_S-_YbJAiNszO0
#       gwLlNQogsTBEqNrpwKM2S1A6alqWpE3ZszoUrcgrMPEGFouu4JdX6jTmgbYLQMFkFVkA4XGbIH03e4HnBpQhgyj_",
#           "abstract": "Maity, Subhankar\u00a0,\u00a0Deroy, Aniket\u00a0,\u00a0Sarkar, Sudeshna\u00a0-\u00a0\u300aSn
#       Computer Science\u300b\u00a0-\u00a02024",
#           "rank": "3"
#         },
#         {
#           "title": "...Advances in MultiModal Large Language Models\u591a\u6a21\u6001...",
#           "url":
#       "http://www.baidu.com/link?url=MFVRco_PoqCzDR_PgXOd3ZfucjWB-G6I-YcP23sDy1JEbpkPSsxrreYaiTPOFRhKPw10FVrjnA_fO4
#       LJuBYjJEJG7sYzr2DyDmfLusuBVR3",
#           "abstract": "...Advances in MultiModal Large Language
#       Models\u591a\u6a21\u6001...\n\n\n\n\n\n\n\n\n2024\u5e741\u670829\u65e5  In the past year, MultiModal Large
#       Language Models (MM-LLMs) have undergone substan-tial advancements, augmenting off-the-shelf LLMs to support
#       MM inputs or outpu...\n\n\n\n\nCSDN\u535a\u5ba2\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d\n\u6682\u505c",
#           "rank": "4"
#         },
#         {
#           "title": "lightweight large language m... - \u76f8\u5173\u8bba\u6587(\u517166892\u7bc7) -
#       \u767e\u5ea6...",
#           "url":
#       "http://www.baidu.com/link?url=cjx3EM5nJoGzYmloZpI-aezaaM_hndp33yAubcrpGTGFRgLroyV8j1O7eXUt0dp7LXdCicjyimWXQr
#       zmmgtwjhesGO6M1uPwV6Cn8nTQVYo_gV73eXoz9EyLAgC8ooySWhboXL5YXOW5MyKO4J285S1yAOd696rwAe5OBTTSEY-heLH26OsnovvNEDb
#       Mxizk",
#           "abstract": "In recent years, large language models (LLMs) and generative AI have revolutionized natural
#       language processing (NLP), offering unprecedented capabilities in education...",
#           "rank": "5"
#         },
#         {
#           "title": "\u3010LRC\u3011...Aware Visual Question Generation with Lightweight M...",
#           "url": "http://www.baidu.com/link?url=Ngb_7bydN6aUyz6MJTVUpzUI6eI0gWGdpPgSXXVBVWrBhfkABrsCt0ZWFX_CU4Pn",
#           "abstract": "\u3010LRC\u3011...Aware Visual Question Generation with Lightweight
#       M...\u6587\u4ef6\u683c\u5f0f\uff1aLRC/Lyric\u00a0-\u00a0HTML\u7248Location-Aware Visual Question Generation
#       with Lightweight Models Nicholas Collin Suwono1,2 Chih Yao Chen1 Tun Min Hung1 Ting-Hao 'Kenneth' Huang3
#       I-Bin Liao4 Yun...arxiv.org/pdf/23...15129\ue62b",
#           "rank": "6"
#         },
#         {
#           "title": "Large Language Model (LLM)",
#           "url":
#       "http://www.baidu.com/link?url=_8nwm028ET_0Iy0hj5120blcz_N3ZK7k7Ad7Z-IPWg-m5_XWrHAbrPXUxRL2CHrab5rU2dXeBltSqS
#       LMzc2_TK",
#           "abstract": "Large Language Model (LLM)\n\n\n\n\n\n\n\n\n2025\u5e742\u670814\u65e5  Large Language Model
#       (LLM) AI-generated audio 17:28 What are Large Language Models? A large language model (LLM) is a generative
#       mathematical model that analyzes ...www.xenonstack.com/blog/large-...\ue62b",
#           "rank": "7"
#         },
#         {
#           "title": "\u5343\u7bc7\u5927\u8bed\u8a00\u6a21\u578b(LLM)\u8bba\u6587\u8c03\u7814\u6574\u7406-\u4e0a -
#       \u77e5\u4e4e",
#           "url": "http://www.baidu.com/link?url=3HpVRM9AOf7NtRcIsilRZkzcfu7SKO0SdQYooM3FpVb-coHRv7Bwz69uLOudduWi",
#           "abstract": "\u5343\u7bc7\u5927\u8bed\u8a00\u6a21\u578b(LLM)\u8bba\u6587\u8c03\u7814\u6574\u7406-\u4e0a -
#       \u77e5\u4e4e2024\u5e747\u670830\u65e5  (1)Training Compute-Optimal Large Language
#       Models\u8ba4\u4e3a\u73b0\u5728\u7684\u5927\u6a21\u578b\u6ca1\u6709\u7ecf\u8fc7\u5145\u5206\u8bad\u7ec3\u7684\
#       u6587\u7ae0(2)Understanding the Effectiveness of Early Weight Averaging ...\n\n\n\n\n\u77e5\u4e4e\ue62b",
#           "rank": "8"
#         }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        3.1452s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG =========================== tool ===========================
# DEBUG [
#         {
#           "title": "\u767e\u5ea6\u7ffb\u8bd1",
#           "url":
#       "http://www.baidu.com/link?url=xECPLKyO4rj8Yr7Pub4BxfX_uWgCx_TohvccjtOzcaZCddRm7xWhQODdimV8iTa9XOFa0np2wkz1ef
#       5q0yC9dVlTADvcNF6HPT6lhvKvwJ31W0VFuTj6ueWSRw4T7BJR0NZ6mBXUyiDKlqtFSapKRcoC5VXzdGqYfYinpnWJ55JLhlmWBsSigV2glfi
#       gJk36",
#           "abstract":
#       "\u767e\u5ea6\u7ffb\u8bd1\n\n\u6cd5\u8bed\ue73c\n\n\n\n\n\u4e2d\u6587\ue73c\n\n\n\n\n\n\n\n\n\ue601\n\n\n0 /
#       2000\n                    \n\n\n\n\n\n\n\n
#       \u70b9\u51fb\u5212\u7ebf\u5355\u8bcd\u53ef\u67e5\u770b\u91ca\u4e49\n
#       \n\n\n\n\n\n\u8f7b\u91cf\u7ea7\u8bed\u8a00\u6a21\u578b\u751f\u6210\u95ee\u9898\n\n\n\n
#       \u590d\u5236\u6210\u529f\n
#       \n\n\n\n\n\n\ue6c2\n\n\n\n\u8bd5\u8bd5\u6587\u6863\u7ffb\u8bd1\u4e0b\u8f7d\u767e\u5ea6\u7ffb\u8bd1\u684c\u976
#       2\u7aef\u767e\u5ea6\u7ffb\u8bd1",
#           "rank": "1"
#         },
#         {
#           "title": "Grands mod\u00e8les de langage - Training | Microsoft Learn",
#           "url":
#       "http://www.baidu.com/link?url=hiFblqt4mbkjkK_FCKbpmyUbhkybVsB-As5sUTpiZgZqjiSnheyWug5qLus7upKun04tInTzTWn32w
#       J4_0hI2hwQ89Zt9klxoFD_EtkKHUwRqkjTpk2JXThe0RCXUxcZafaNUKBKST314sUHqsJ1ReVmhGAWNtRx2X0xCbfaaA5QmnAcMl5gJsmXMlA
#       8UCVN",
#           "abstract": "Grands mod\u00e8les de langage - Training | Microsoft Learn2025\u5e743\u670831\u65e5  Les
#       mod\u00e8les de langage volumineux peuvent effectuer diverses t\u00e2ches en langage naturel, comme
#       :Classification R\u00e9sum\u00e9 Conversion G\u00e9n\u00e9ration de ...Microsoft\ue62b",
#           "rank": "2"
#         },
#         {
#           "title": "NVIDIA NGC | NVIDIA",
#           "url":
#       "http://www.baidu.com/link?url=1tMCUWVv9UUCGnCQeGqS0s7WNzoOdk3n9X-gQuKYPXV12o2jOAy26PTSqMHK8W0YAt8eJvbmPVFyA3
#       QiDaed_K",
#           "abstract": "NVIDIA NGC | NVIDIANVIDIA NGC\u2122propose une collection de services Cloud enti\u00e8rement
#       g\u00e9r\u00e9s, notammentNeMo LLM,BioNemoetRiva Studiopour NLU et les solutions d\u2019IA vocale. Les
#       exper...www.nvidia.com/fr-fr/gpu-clo...\ue62b",
#           "rank": "3"
#         },
#         {
#           "title": "GitLab Duo | GitLab",
#           "url":
#       "http://www.baidu.com/link?url=xUrDYb0g1BGXQ0o7b9TXuHAdM5O7wuN5UimFNu4kStLRZmp1M-kxla5GuHFpZQIGP7mZCOtFvNCv83
#       PlbcmMr_",
#           "abstract": "GitLab Duo | GitLab\n\n\n\n\n\n\n\n\nr\u00e9sultats des suggestions de code sont attendus
#       pour les langages que les api vertex ai codey google prennent directement en charge\u00a0: c++, c#, go,
#       google sql, java, javascrip...about.gitlab.com/fr-fr/gitlab-...\ue62b",
#           "rank": "4"
#         },
#         {
#           "title": "Coverz",
#           "url": "http://www.baidu.com/link?url=1tMCUWVv9UUCGnCQeGqS0s7WNzoOdk3n9X-gQuKYPXVFkmsDPD2k_2C9YBME62HT",
#           "abstract": "Coverz\n\n\n\n\n\n\n\n\nMon\u00e9tisation innovante dans les jeux gratuits En 2025, les jeux
#       multijoueurs gratuits ont r\u00e9volutionn\u00e9 leurs mod\u00e8les \u00e9conomiques pour parvenir \u00e0 un
#       \u00e9quilibre d\u00e9licat : ...www.coverz.org/\ue62b",
#           "rank": "5"
#         },
#         {
#           "title": "Google I/O : une \u00e9dition 2023 sous la domination de l...",
#           "url":
#       "http://www.baidu.com/link?url=1tMCUWVv9UUCGnCQeGqS0svhUYk6JEB6z2PkOWth3rlf1jmWEfiMgOi5Ax4Y5lO2hQwCRtVy3E284y
#       BlT9KUhBpWcXC8Q59qoT_JzQYJmIn4OkGY66FzhOsGv5xieP0tIbFJsmiRSsgADeNmZZa7Q0i2-dZzwWF3EdUB1N11gm7",
#           "abstract": "Google I/O : une \u00e9dition 2023 sous la domination de l...2023\u5e745\u670816\u65e5
#       Google a donc pr\u00e9sent\u00e9 PaLM 2, son nouveau grand mod\u00e8le de langage. Si la premi\u00e8re
#       version ciblait les r\u00e9ponses pertinentes \u00e0 des
#       probl\u00e9matiq...www.nextinpact.com/article/716...\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d\n\u6682\u505c"
#       ,
#           "rank": "6"
#         },
#         {
#           "title": "ES Tractebel L1",
#           "url":
#       "http://www.baidu.com/link?url=1tMCUWVv9UUCGnCQeGqS0w-WbWumDfF0zHh9OobYdeHrkegwZXrHHCUN2_OTt27hT87QvWQdjNaCVo
#       X8iY93I_",
#           "abstract": "ES Tractebel L1\n\n\n\n\n\n\n\n\n2025\u5e743\u670819\u65e5  Tu es en BAC+5 ou titulaire
#       d\u2019un dipl\u00f4me d\u2019ing\u00e9nieur en g\u00e9nie civil. Tu as une ma\u00eetrise le langage de
#       programmation Python ainsi qu\u2019Open Office Tu fais pre...www.engie.com/taxonomy/term/1...\ue62b",
#           "rank": "7"
#         },
#         {
#           "title": "\u00c0 propos des mod\u00e8les de g\u00e9n\u00e9ration dans l'IA g\u00e9n...",
#           "url":
#       "http://www.baidu.com/link?url=0xYdxEaNS_3xcKjtZKBbCXPXt_WvBxKsVTqBuJf7L5hd0tUpV76ujGTy43C1xLSAT5glpyUcXA6QMi
#       VMoFCzcCsmxG7itmhclAc09zbE5R1K8aFgSGZBNtRa4LQqk9Ni",
#           "abstract": "\u00c0 propos des mod\u00e8les de g\u00e9n\u00e9ration dans l'IA
#       g\u00e9n...2024\u5e7411\u670815\u65e5  Vous pouvez demander \u00e0 un mod\u00e8le de g\u00e9n\u00e9ration de
#       g\u00e9n\u00e9rer du texte. Voici quelques exemples de cas d'utilisation pour les mod\u00e8les de
#       g\u00e9n\u00e9r...Oracle\ue62b\n\n\ue680\n\u64ad\u62a5\n\n\n\ue67d\n\u6682\u505c",
#           "rank": "8"
#         }
#       ]
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG * Time:                        1.5887s
# DEBUG **********************  TOOL METRICS  **********************
# DEBUG ======================== assistant =========================
# DEBUG ### Top 3 Web Results for: lightweight large language models for generating questions from a user query
#
#       #### English Source 1
#       - **Title:** Location-Aware Visual Question Generation with Lightweight Models
#       - **Summary:** This paper explores visual question generation (VQG) using lightweight models. It introduces a
#       location-aware approach to improve the quality of generated questions, particularly focusing on spatial
#       relationships within images. The research emphasizes efficiency and reduced computational cost, making it
#       relevant to the prompt.
#       - **Link:** http://www.baidu.com/link?url=Ngb_7bydN6aUyz6MJTVUpzUI6eI0gWGdpPgSXXVBVWrBhfkABrsCt0ZWFX_CU4Pn
#       - **Language:** English
#
#       #### English Source 2
#       - **Title:** Investigating Large Language Models for Prompt... - Baidu Xueshu
#       - **Summary:** This study investigates the efficacy of Large Language Models in prompt engineering. While the
#       title is broad, the research likely touches upon aspects of model efficiency and resource utilization when
#       generating prompts, and thus is related to the use of lightweight LLMs.
#       - **Link:**
#       http://www.baidu.com/link?url=YLZ1wMrolzvIhBHYMs-cZmivKPWpHrFeZfd3v3NnOFVQ1eEM9hQbpFipmmzt8hR1a4v9pP6FJDttZFs
#       K2ESg-EOECE3C89YcBzqN5BbLn72fa2zQvXnXe4Evtojjd5SpZg5gHAbs5LI0vJfBweDkc1FhxjvjnAoRwVQKvHVdW1OL1ykVreC9zGssA8b2
#       GAIqrjjtWv4AQ-UHfyYnX0gF9TuI6xPdEpiw739eHZGy6U5LXCgojJaoRkAZ7zP0bdD7uwpVmVodLzgKyzYCad6JgbYHfa_S-_YbJAiNszO0g
#       wLlNQogsTBEqNrpwKM2S1A6alqWpE3ZszoUrcgrMPEGFouu4JdX6jTmgbYLQMFkFVkA4XGbIH03e4HnBpQhgyj_
#       - **Language:** English
#
#       #### French Source 1
#       - **Title:** À propos des modèles de génération dans l'IA gén...
#       - **Summary:** This article discusses generative models in generative AI, including the generation of text.
#       While not explicitly about lightweight models, it provides context on the types of models used for question
#       generation and could indirectly reference more efficient options.
#       - **Link:**
#       http://www.baidu.com/link?url=0xYdxEaNS_3xcKjtZKBbCXPXt_WvBxKsVTqBuJf7L5hd0tUpV76ujGTy43C1xLSAT5glpyUcXA6QMiV
#       MoFCzcCsmxG7itmhclAc09zbE5R1K8aFgSGZBNtRa4LQqk9Ni
#       - **Language:** French
#
#       ### Observations
#       - The search results are limited in directly addressing "lightweight LLMs for question generation". Many
#       results focus on general LLMs or VQG without emphasizing the lightweight aspect.
#       - There's a noticeable presence of research papers on visual question generation, suggesting that the
#       combination of visual context and question generation is an active area of research.
#       - The French results touch upon general generative models, but don't pinpoint efficient models specifically.
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=6573, output=796, total=7369
# DEBUG * Time:                        4.2052s
# DEBUG * Tokens per second:           189.2905 tokens/s
# DEBUG * Time to first token:         0.3496s
# DEBUG ************************  METRICS  *************************
# DEBUG ---------------- Google Response Stream End ----------------
# DEBUG Added 4 Messages to AgentMemory
# DEBUG Added AgentRun to AgentMemory
# DEBUG Logging Agent Run
# DEBUG *** Agent Run End: 955fab8c-88b1-4205-9a14-a835b55b975d ****
# DEBUG Updated team context with member name: BaiduSearch engine agent
# DEBUG ****** Agent ID: 4dfaa69a-de4f-48bd-b355-d28ef980942b ******
# DEBUG ***** Session ID: c61c09fa-0bc1-418c-bdb2-cc344472be62 *****
# DEBUG ** Agent Run Start: 18e50544-91c5-452f-bc53-e8319bba34e8 ***
# DEBUG --------------- Google Response Stream Start ---------------
# DEBUG ----------------- Model: gemini-2.0-flash ------------------
# DEBUG ========================== system ==========================
# DEBUG <your_role>
#       Research academic papers and scholarly content
#       </your_role>
#
#       <instructions>
#
#           You are a highly skilled academic research assistant specializing in scientific papers, peer-reviewed
#       articles, and scholarly discussions. Your task is to conduct a comprehensive search on the given topic using
#       academic tools such as Google Scholar and ArXiv.
#
#       Research Topic: {topic}
#       Research Preferences: {preferences}
#       Additional Instructions: {instructions}
#
#       Your Responsibilities:
#       - Search for the **most recent and relevant scholarly articles**, preprints, and academic discussions related
#       to the given topic.
#       - Focus on peer-reviewed publications, high-impact journals, and reputable scientific sources.
#       - For each source, provide:
#         1. **Title of the paper or article**
#         2. **Authors and publication year**
#         3. **A concise summary (3–5 sentences)** covering objectives, methodology, and key findings
#         4. **Link to the full text or citation URL**
#       - Identify any recurring themes, emerging sub-topics, or open research questions.
#       - Avoid content from blogs, news sites, or non-scholarly sources.
#
#       Output Format:
#       - Markdown structured list
#       - Group articles by thematic relevance if applicable
#       - Ensure all links are active and citations are correctly formatted
#
#       Your final output should serve as a **research digest** that a scientist, PhD student, or technical leader
#       could use as a reference for deeper investigation into the topic.
#
#       Example Format:
#
#       ### Topic: {topic}
#
#       #### Academic Source 1
#       - **Title:** ...
#       - **Authors / Year:** ...
#       - **Summary:** ...
#       - **Link:** ...
#
#       (...repeat for other articles...)
#
#       #### Observations
#       - Recurring themes: ...
#       - Notable gaps or debates: ...
#       - Suggested next steps for deeper research: ...
#
#
#       </instructions>
#
#       <additional_information>
#       - Use markdown to format your answers.
#       - Your name is: Academic Paper Researcher.
#       </additional_information>
# DEBUG =========================== user ===========================
# DEBUG You are a member of a team of agents that collaborate to complete a task.
#
#       <task>
#       Research and provide information on the best lightweight large language models for generating questions from
#       a user query. Focus on models that are efficient in terms of computational resources and memory footprint.
#       </task>
#
#       <expected_output>
#       A list of lightweight LLMs suitable for question generation, along with their key features, performance
#       metrics, and use cases. Cite all sources.
#       </expected_output>
#
#       <team_context>
#       The research topic is 'what is the best lightweight large language models for generating questions from a
#       user query?'
#       </team_context>
# DEBUG ======================== assistant =========================
# DEBUG ### Topic: Lightweight LLMs for Question Generation
#
#       Here's a research digest on lightweight Large Language Models (LLMs) suitable for generating questions from a
#       user query, focusing on efficiency in terms of computational resources and memory footprint.
#
#       #### Academic Source 1
#       - **Title:** DistilBERT, a distilled version of BERT: smaller, faster, cheaper and lighter
#       - **Authors / Year:** Victor Sanh, Lisa Debut, Julien Chaumond, Thomas Wolf / 2019
#       - **Summary:** This paper introduces DistilBERT, a distilled version of BERT. It retains 97% of BERT's
#       language understanding capabilities while being 40% smaller and 60% faster. The distillation process involves
#       a triple loss combining language modeling, distillation, and cosine-distance losses. This makes it suitable
#       for question generation where computational resources are limited.
#       - **Link:** Not directly available via arXiv search; search on Google Scholar for "DistilBERT" to find the
#       paper.
#
#       #### Academic Source 2
# ...
#       - **Channel:** {channel_name}
#       - **Published on:** {upload_date}
#       - **Video Link:** {video_url}
#
#       #### Summary
#       {summary_text}
#
#       #### Key Points
#       - Point 1
#       - Point 2
#       - ...
#
#       #### Tools / Frameworks Mentioned
#       - ...
#
#
#
#       </instructions>
#
#       <additional_information>
#       - Use markdown to format your answers.
#       </additional_information>
# DEBUG =========================== user ===========================
# DEBUG You are a member of a team of agents that collaborate to complete a task.
#
#       <task>
#       Please create a scientific and technical report based on the shared context about the best lightweight large
#       language models for generating questions from a user query.
#       </task>
#
#       <expected_output>
#       A scientific and technical report with the following sections: Introduction, Literature Review, Web Insights
#       & Trends, YouTube Multimedia Insights, Professional and Social Commentary, Synthesis & Cross-Analysis, and
#       Conclusions & Recommendations.
#       </expected_output>
#
#       <team_context>
#       Academic Paper Researcher found that DistilBERT, MobileBERT, TinyBERT and ALBERT are good candidates.
#       Linkedin Researcher found that ChatGLM and lmqg are potential Lightweight LLMs. Search Engine agent found
#       research papers on visual question generation. YouTube agent found that Fine-Tuning DistilBERT and Other
#       Models are good for question answering system
#       </team_context>
# DEBUG ======================== assistant =========================
# DEBUG Okay, I understand. I will analyze the YouTube video content and provide insights to be incorporated into the
#       final report, focusing on lightweight LLMs for question generation.
#
#       Please provide the YouTube video URL so I can begin.
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=744, output=45, total=789
# DEBUG * Time:                        0.6975s
# DEBUG * Tokens per second:           64.5130 tokens/s
# DEBUG * Time to first token:         0.4196s
# DEBUG ************************  METRICS  *************************
# DEBUG ---------------- Google Response Stream End ----------------
# DEBUG Added 2 Messages to AgentMemory
# DEBUG Added AgentRun to AgentMemory
# DEBUG Logging Agent Run
# DEBUG *** Agent Run End: 8e55a5fb-4baa-4a2e-9026-dce473caf31d ****
# DEBUG Updated team context with member name: YouTube agent
# ERROR    Error from Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your
#          current quota, please check your plan and billing details. For more information on this error, head to:
#          https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type':
#          'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric':
#          'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId':
#          'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model':
#          'gemini-2.0-flash'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links':
#          [{'description': 'Learn more about Gemini API quotas', 'url':
#          'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type':
#          'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '59s'}]}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\agno\models\google\gemini.py:259, in Gemini.invoke_stream(self, messages)
#     258 try:
# --> 259     yield from self.get_client().models.generate_content_stream(
#     260         model=self.id,
#     261         contents=formatted_messages,
#     262         **request_kwargs,
#     263     )
#     264 except (ClientError, ServerError) as e:
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\google\genai\models.py:5096, in Models.generate_content_stream(self, model, contents, config)
#    5092 if i == 1:
#    5093   # First request gets a function call.
#    5094   # Then get function response parts.
#    5095   # Yield chunks only if there's no function response parts.
# -> 5096   for chunk in response:
#    5097     if not function_map:
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\google\genai\models.py:4008, in Models._generate_content_stream(self, model, contents, config)
#    4006 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4008 for response_dict in self._api_client.request_streamed(
#    4009     'post', path, request_dict, http_options
#    4010 ):
#    4012   if self._api_client.vertexai:
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\google\genai\_api_client.py:693, in BaseApiClient.request_streamed(self, http_method, path, request_dict, http_options)
#     689 http_request = self._build_request(
#     690     http_method, path, request_dict, http_options
#     691 )
# --> 693 session_response = self._request(http_request, stream=True)
#     694 for chunk in session_response.segments():
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\google\genai\_api_client.py:591, in BaseApiClient._request(self, http_request, stream)
#     590 response = self._httpx_client.send(httpx_request, stream=stream)
# --> 591 errors.APIError.raise_for_response(response)
#     592 return HttpResponse(
#     593     response.headers, response if stream else [response.text]
#     594 )
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\google\genai\errors.py:101, in APIError.raise_for_response(cls, response)
#     100 if 400 <= status_code < 500:
# --> 101   raise ClientError(status_code, response_json, response)
#     102 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '59s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ModelProviderError                        Traceback (most recent call last)
# Cell In[14], line 108
#     106 if __name__ == "__main__":
#     107     import asyncio
# --> 108     asyncio.get_event_loop().run_until_complete(main())
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# Cell In[14], line 100, in main()
#      99 async def main():
# --> 100     manager_team_.print_response(
#     101         message="Start the repport on the topic: 'what is the best lightweight large language models for generating questions from a user query?'",
#     102         stream=True,
#     103         stream_intermediate_steps=True,
#     104     )
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\agno\team\team.py:1876, in Team.print_response(self, message, stream, stream_intermediate_steps, session_id, user_id, show_message, show_reasoning, show_full_reasoning, console, tags_to_include_in_markdown, audio, images, videos, files, markdown, **kwargs)
#    1873     stream = False
#    1875 if stream:
# -> 1876     self._print_response_stream(
#    1877         message=message,
#    1878         console=console,
#    1879         show_message=show_message,
#    1880         show_reasoning=show_reasoning,
#    1881         show_full_reasoning=show_full_reasoning,
#    1882         tags_to_include_in_markdown=tags_to_include_in_markdown,
#    1883         session_id=session_id,
#    1884         user_id=user_id,
#    1885         audio=audio,
#    1886         images=images,
#    1887         videos=videos,
#    1888         files=files,
#    1889         markdown=markdown,
#    1890         stream_intermediate_steps=stream_intermediate_steps,
#    1891         **kwargs,
#    1892     )
#    1893 else:
#    1894     self._print_response(
#    1895         message=message,
#    1896         console=console,
#    (...)   1908         **kwargs,
#    1909     )
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\agno\team\team.py:2278, in Team._print_response_stream(self, message, console, show_message, show_reasoning, show_full_reasoning, tags_to_include_in_markdown, session_id, user_id, audio, images, videos, files, markdown, stream_intermediate_steps, **kwargs)
#    2275 # Dict to track member response panels by member_id
#    2276 member_response_panels = {}
# -> 2278 for resp in stream_resp:
#    2279     if team_markdown is None:
#    2280         if markdown:
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\agno\team\team.py:940, in Team._run_stream(self, run_response, run_messages, session_id, user_id, stream_intermediate_steps)
#     938 full_model_response = ModelResponse()
#     939 model_stream = self.model.response_stream(messages=run_messages.messages)  # type: ignore
# --> 940 for model_response_chunk in model_stream:
#     941     # If the model response is an assistant_response, yield a RunResponse
#     942     if model_response_chunk.event == ModelResponseEvent.assistant_response.value:
#     943         should_yield = False
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\agno\models\base.py:514, in Model.response_stream(self, messages)
#     512 # Generate response
#     513 assistant_message.metrics.start_timer()
# --> 514 yield from self.process_response_stream(
#     515     messages=messages, assistant_message=assistant_message, stream_data=stream_data
#     516 )
#     517 assistant_message.metrics.stop_timer()
#     519 # Populate assistant message from stream data
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\agno\models\base.py:486, in Model.process_response_stream(self, messages, assistant_message, stream_data)
#     480 def process_response_stream(
#     481     self, messages: List[Message], assistant_message: Message, stream_data: MessageData
#     482 ) -> Iterator[ModelResponse]:
#     483     """
#     484     Process a streaming response from the model.
#     485     """
# --> 486     for response_delta in self.invoke_stream(messages=messages):
#     487         model_response_delta = self.parse_provider_response_delta(response_delta)
#     488         yield from self._populate_stream_data_and_assistant_message(
#     489             stream_data=stream_data, assistant_message=assistant_message, model_response=model_response_delta
#     490         )
#
# File c:\Users\drief\Desktop\VST_\.venv\Lib\site-packages\agno\models\google\gemini.py:266, in Gemini.invoke_stream(self, messages)
#     264 except (ClientError, ServerError) as e:
#     265     log_error(f"Error from Gemini API: {e}")
# --> 266     raise ModelProviderError(
#     267         message=e.response, status_code=e.code, model_name=self.name, model_id=self.id
#     268     ) from e
#     269 except Exception as e:
#     270     log_error(f"Unknown error from Gemini API: {e}")
#
# ModelProviderError: <Response [429 Too Many Requests]>

# %%
# Agent to determine the task type (route or collaborate)
# using Gemini model with API key

task_type_agent = Agent(
    name="Task type agent",
    model=Gemini(id="gemini-2.0-flash",
                     api_key="AIzaSyCiIkB8D_Y-utNrWKLDa8Aozlru4C4SpPE"), 
    show_tool_calls=False,
    debug_mode=False,
    instructions=[
        """You are an expert reasoning agent tasked with determining the appropriate operational mode based on the nature of the user’s query. You must analyze the query and return one of the following two modes:

"route" — if the query is clear, specific, and requires a direct answer or single-agent execution.

"collaborate" — if the query is open-ended, exploratory, complex, or would benefit from multi-agent interaction, iterative reasoning, or cooperative planning.

Your output must be strictly limited to one of these two values: "route" or "collaborate".

User query:
{user_query}

Returned mode:
{mode}"""
    ],
    )
#task_type_agent.print_response("Write a python script for fibonacci series and display the result till the 10th number")
print(task_type_agent.run("Write a python script for fibonacci series and display the result till the 10th number").content)
#task_type_agent.print_response("What is the best lightweight large language models for generating questions from a user query?")
print(task_type_agent.run("What is the best lightweight large language models for generating questions from a user query?").content)
# Out:
# route
#
# collaborate
